# %% [markdown]
# ## 1. Census Data

# %%
import pandas as pd
import re

# %%
cens = pd.read_csv('2016Census_G01_VIC_SSC.csv')
cens = cens.iloc[:,[0,3]]
# Change column names
cens.columns= ['SSC','TotPop']
# Delete rows with 0 population
cens = cens.loc[cens.TotPop!=0]
# Delete "SSC" in the first column
i=0
while i < cens.shape[0]:
    cens.iloc[i,0] = cens.iloc[i,0][3:]
    i = i+1
cens.SSC = cens.SSC.astype('int64')

# %%
# Drop the record with 22543
cens.drop(index=cens[cens.SSC==22543].index,inplace=True)

# %%
cens.head()
# Out:
#      SSC  TotPop
# 1  20002    8184
# 2  20003    3897
# 4  20005     171
# 6  20007      59
# 7  20008      71

# %% [markdown]
# ### SSC Data

# %%
ssc=pd.read_csv('SSC_2016_AUST.csv')
ssc=ssc[ssc.STATE_NAME_2016=='Victoria'].groupby(['SSC_CODE_2016','SSC_NAME_2016']).sum()
ssc.reset_index(inplace=True)
ssc=ssc[['SSC_CODE_2016','SSC_NAME_2016']]
ssc.columns=['SSC','Suburb']
ssc.head()
# Out:
#      SSC             Suburb
# 0  20001           Abbeyard
# 1  20002  Abbotsford (Vic.)
# 2  20003         Aberfeldie
# 3  20004          Aberfeldy
# 4  20005            Acheron

# %%
for i in range(len(ssc)):
    ssc.iloc[i,1]=re.match(r'[a-zA-Z ]*', ssc.iloc[i,1]).group(0)
    ssc.iloc[i,1]=ssc.iloc[i,1].strip(' ')
cens.SSC = cens.SSC.astype('int64')

# %%
print(ssc.shape)
print(cens.shape)
# Out:
# (2931, 2)
# (2817, 2)

# %%
ssc.head()
# Out:
#      SSC      Suburb
# 0  20001    Abbeyard
# 1  20002  Abbotsford
# 2  20003  Aberfeldie
# 3  20004   Aberfeldy
# 4  20005     Acheron

# %% [markdown]
# ### Merge Census and SSC

# %%
sub_pop = pd.merge(ssc, cens, on='SSC', how='inner')
sub_pop = sub_pop[['Suburb','TotPop']]
sub_pop.Suburb=sub_pop.Suburb.str.upper()
sub_pop.head()
# Out:
#          Suburb  TotPop
# 0    ABBOTSFORD    8184
# 1    ABERFELDIE    3897
# 2       ACHERON     171
# 3  ADAMS ESTATE      59
# 4     ADDINGTON      71

# %%
sub_pop[sub_pop['Suburb']=='TOTTENHAM']
# Out:
# Empty DataFrame
# Columns: [Suburb, TotPop]
# Index: []

# %%
sub_pop.head()
# Out:
#          Suburb  TotPop
# 0    ABBOTSFORD    8184
# 1    ABERFELDIE    3897
# 2       ACHERON     171
# 3  ADAMS ESTATE      59
# 4     ADDINGTON      71

# %% [markdown]
# ## 2. Crime Data

# %%
off = pd.read_csv('Offence Data.csv')

# %%
off = off.loc[:,['Year ending December','Postcode','Suburb/Town Name','Offence Count']]
# change column names
off.columns=['Year','Postcode','Suburb','OffenceCount']
# filter data with year 2018
off = off[off.Year == 2018]
off=off[['Postcode','Suburb','OffenceCount']]
# Replace ',' with '' in OffenceCount
off.OffenceCount = pd.Series(off.OffenceCount).str.replace(',','',regex=False)
# Change datatype of OffenceCount column
off.OffenceCount = pd.to_numeric(off.OffenceCount)
off.head()
# Out:
#        Postcode     Suburb  OffenceCount
# 30412      3000  MELBOURNE           709
# 30413      3000  MELBOURNE           135
# 30414      3000  MELBOURNE           569
# 30415      3000  MELBOURNE           114
# 30416      3000  MELBOURNE           187

# %%
off = off.groupby(['Suburb','Postcode'])[['OffenceCount']].sum()
off.reset_index(inplace=True)
off.head()
# Out:
#        Suburb  Postcode  OffenceCount
# 0    ABBEYARD      3737             2
# 1  ABBOTSFORD      3067          1478
# 2  ABERFELDIE      3040            97
# 3     ACHERON      3714             5
# 4   ADDINGTON      3352             4

# %%
off.shape
# Out:
# (2424, 3)

# %% [markdown]
# ## 3. Crime Rate

# %%
pop=sub_pop
print(off.shape)
print(pop.shape)
# Out:
# (2424, 3)
# (2817, 2)

# %%
# Check how many suburbs in offence are not in the population table.
i = 0
excep_list=[]
while i < off.shape[0]:
    if off.iloc[i,0] not in list(pop.Suburb):
#         print('offence data suburb', off.iloc[i,0], 'is not in census')
        excep_list.append(off.iloc[i,0])
    i = i+1
print(len(excep_list))
# Out:
# 148

# %%
pop[pop['Suburb']=='WOODEND']
# Out:
#        Suburb  TotPop
# 2713  WOODEND    5806

# %%
merge = pd.merge(off, pop, on='Suburb', how='right')
merge.head()
# Out:
#           Suburb  Postcode  OffenceCount  TotPop
# 0     ABBOTSFORD    3067.0        1478.0    8184
# 1     ABERFELDIE    3040.0          97.0    3897
# 2        ACHERON    3714.0           5.0     171
# 3      ADDINGTON    3352.0           4.0      71
# 4  ADELAIDE LEAD    3465.0           3.0      81

# %%
merge.shape
# Out:
# (2830, 4)

# %%
merge=pd.DataFrame.drop_duplicates(merge)

# %%
merge.shape
# Out:
# (2830, 4)

# %%
merge['CrimeRate']= round(merge.OffenceCount/merge.TotPop,4)
merge.head()
# Out:
#           Suburb  Postcode  OffenceCount  TotPop  CrimeRate
# 0     ABBOTSFORD    3067.0        1478.0    8184     0.1806
# 1     ABERFELDIE    3040.0          97.0    3897     0.0249
# 2        ACHERON    3714.0           5.0     171     0.0292
# 3      ADDINGTON    3352.0           4.0      71     0.0563
# 4  ADELAIDE LEAD    3465.0           3.0      81     0.0370

# %%
# merge.to_csv('2018CrimeRate_Data.csv',index = False)

# %%
merge[merge['TotPop'].isnull()].shape
# Out:
# (0, 5)

# %%
merge[merge['OffenceCount'].isnull()].shape
# Out:
# (538, 5)

# %%
merge[merge['Suburb']=='MALVERN']
# Out:
#        Suburb  Postcode  OffenceCount  TotPop  CrimeRate
# 1244  MALVERN    3144.0         760.0   10066     0.0755

# %%
# List suburbs without data
suburb_withoutData=merge[merge.isnull().any(axis=1)].Suburb.tolist()
suburb_withoutData
# Out:
# ['ADAMS ESTATE',
#  'AGNES',
#  'ALLAMBEE SOUTH',
#  'ANNUELLO',
#  'APPIN',
#  'ARCHIES CREEK',
#  'AREEGRA',
#  'ARNOLD WEST',
#  'AUBREY',
#  'AVONMORE',
#  'BAEL BAEL',
#  'BAGSHOT NORTH',
#  'BALINTORE',
#  'BALLAPUR',
#  'BALOOK',
#  'BAMGANIE',
#  'BANYAN',
#  'BARINGHUP WEST',
#  'BARKLY',
#  'BARKSTEAD',
#  'BAROMI',
#  'BARRAPORT WEST',
#  'BARUNAH PLAINS',
#  'BARWIDGEE',
#  'BASALT',
#  'BATHUMI',
#  'BAYINDEEN',
#  'BEAZLEYS BRIDGE',
#  'BEENAK',
#  'BELLELLEN',
#  'BENDOC',
#  'BENNISON',
#  'BERRIMAL',
#  'BETE BOLONG NORTH',
#  'BIG DESERT',
#  'BIG PATS CREEK',
#  'BIRCHIP WEST',
#  'BLACKWARRY',
#  'BLOWHARD',
#  'BOCHARA',
#  'BOGONG',
#  'BOHO SOUTH',
#  'BOIGBEAT',
#  'BOINKA',
#  'BOLTON',
#  'BOOLARONG',
#  'BOOLITE',
#  'BOOMAHNOOMOONAH',
#  'BOONAH',
#  'BOORCAN',
#  'BOORHAMAN EAST',
#  'BOOROOL',
#  'BORNES HILL',
#  'BOSTOCKS CREEK',
#  'BOWMANS FOREST',
#  'BOXWOOD',
#  'BRADVALE',
#  'BREAKAWAY CREEK',
#  'BREWSTER',
#  'BRIDGEWATER NORTH',
#  'BRIMBOAL',
#  'BRINGALBERT',
#  'BRIT BRIT',
#  'BROOKVILLE',
#  'BROUGHTON',
#  'BRUARONG',
#  'BRUMBY',
#  'BUCKLEY SWAMP',
#  'BUDGERUM EAST',
#  'BULDAH',
#  'BULLAHARRE',
#  'BULLIOH',
#  'BUNDALONG SOUTH',
#  'BUNG BONG',
#  'BUNGADOR',
#  'BUNGAL',
#  'BUNGEET WEST',
#  'BUNGIL',
#  'BUNGULUKE',
#  'BURKES BRIDGE',
#  'BURKES FLAT',
#  'BURRAMINE SOUTH',
#  'BUTCHERS RIDGE',
#  'CADELLO',
#  'CALLAWADDA',
#  'CALLIGNEE NORTH',
#  'CALLIGNEE SOUTH',
#  'CANARY ISLAND',
#  'CANNIE',
#  'CARALULUP',
#  'CARGERIE',
#  'CARINA',
#  'CARINGAL',
#  'CARRON',
#  'CASSILIS',
#  'CASTLE CREEK',
#  'CATHKIN',
#  'CATUMNAL',
#  'CHEPSTOWE',
#  'CHEWTON BUSHLANDS',
#  'CHILDERS',
#  'CHILTERN VALLEY',
#  'CHINANGIN',
#  'CHIRRIP',
#  'CHOCOLYN',
#  'CLARETOWN',
#  'CLEAR LAKE',
#  'CLOVER FLAT',
#  'COCAMBA',
#  'COKUM',
#  'COLAC COLAC',
#  'COLBROOK',
#  'CONNEWIRRICOO',
#  'COOJAR',
#  'COONOOER WEST',
#  'CORACK EAST',
#  'CORAL BANK',
#  'COSGROVE SOUTH',
#  'COSTERFIELD',
#  'COTSWOLD',
#  'COWLEYS CREEK',
#  'CROSS ROADS',
#  'CULLA',
#  'CUNDARE NORTH',
#  'CURDIES RIVER',
#  'DALTONS BRIDGE',
#  'DANDONGADALE',
#  'DAWSON',
#  'DEDDICK VALLEY',
#  'DELATITE',
#  'DENICULL CREEK',
#  'DERGHOLM',
#  'DIGGORA',
#  'DOCKERS PLAINS',
#  'DOCTORS FLAT',
#  'DORODONG',
#  'DOUGLAS',
#  'DREEITE SOUTH',
#  'DRIK DRIK',
#  'DROPMORE',
#  'DRUMMARTIN',
#  'DUMBALK NORTH',
#  'DUNLUCE',
#  'DUNNEWORTHY',
#  'DUNROBIN',
#  'DUTSON',
#  'DUTTON WAY',
#  'EAST GEELONG',
#  'EAST SALE',
#  'EAST WANGARATTA',
#  'EASTVILLE',
#  'EDI UPPER',
#  'ELINGAMITE',
#  'ELINGAMITE NORTH',
#  'EMU',
#  'EMU CREEK',
#  'ENGLEFIELD',
#  'ENSAY NORTH',
#  'ESMOND',
#  'FAIRBANK',
#  'FERN HILL',
#  'FIERY FLAT',
#  'FLAGGY CREEK',
#  'FLYNNS CREEK',
#  'FOXHOW',
#  'FRENCHMANS',
#  'FUMINA',
#  'FUMINA SOUTH',
#  'GAFFNEYS CREEK',
#  'GANNAWARRA',
#  'GATUM',
#  'GAZETTE',
#  'GELANTIPY',
#  'GELLIBRAND LOWER',
#  'GERMANIA',
#  'GERRIGERRUP',
#  'GHIN GHIN',
#  'GIL GIL',
#  'GILDEROY',
#  'GIPSY POINT',
#  'GLEN CREEK',
#  'GLEN VALLEY',
#  'GLENDONALD',
#  'GLENGOWER',
#  'GLENLEE',
#  'GLENLOFTY',
#  'GLENLOGIE',
#  'GLENLUCE',
#  'GLENMORE',
#  'GLENORMISTON NORTH',
#  'GOLDIE',
#  'GOON NURE',
#  'GOOROC',
#  'GOWANFORD',
#  'GOWANGARDIE',
#  'GOWAR EAST',
#  'GOWER',
#  'GRAYS BRIDGE',
#  'GRE GRE',
#  'GRE GRE NORTH',
#  'GREDGWIN',
#  'GREEN GULLY',
#  'GREENWALD',
#  'GUNYAH',
#  'GYMBOWEN',
#  'HANSONVILLE',
#  'HAWKHURST',
#  'HAZEL PARK',
#  'HEATHCOTE SOUTH',
#  'HENSLEY PARK',
#  'HEYTESBURY LOWER',
#  'HIAMDALE',
#  'HILGAY',
#  'HINNOMUNJIE',
#  'HOMEBUSH',
#  'HUNTERSTON',
#  'IRISHTOWN',
#  'IRREWILLIPE EAST',
#  'JACOB CREEK',
#  'JEFFCOTT',
#  'JERUK',
#  'JIL JIL',
#  'JOEL SOUTH',
#  'JOYCES CREEK',
#  'KALPIENUNG',
#  'KAMAROOKA NORTH',
#  'KANAGULK',
#  'KANUMBRA',
#  'KANYA',
#  'KARABEAL',
#  'KARIAH',
#  'KARYRIE',
#  'KATAMATITE EAST',
#  'KEELY',
#  'KENMARE',
#  'KINNABULLA',
#  'KINYPANIAL',
#  'KIRWANS BRIDGE',
#  'KITHBROOK',
#  'KNEBSWORTH',
#  'KOALLAH',
#  'KONONGWOOTONG',
#  'KOOLOONONG',
#  'KOONDA',
#  'KOOROOCHEANG',
#  'KOOROOMAN',
#  'KUNAT',
#  'KURRACA',
#  'KURRACA WEST',
#  'KYNETON SOUTH',
#  'KYVALLEY',
#  'LADYS PASS',
#  'LAEN EAST',
#  'LAEN NORTH',
#  'LAH',
#  'LAKE CONDAH',
#  'LAKE MUNDI',
#  'LAKE WONGAN',
#  'LANDSBOROUGH WEST',
#  'LANG LANG EAST',
#  'LANGDONS HILL',
#  'LANGKOOP',
#  'LAWLER',
#  'LAWRENCE',
#  'LEICHARDT',
#  'LEONGATHA NORTH',
#  'LESLIE MANOR',
#  'LICOLA NORTH',
#  'LILLIPUT',
#  'LIMA',
#  'LIMESTONE',
#  'LINDSAY',
#  'LINDSAY POINT',
#  'LINGA',
#  'LITCHFIELD',
#  'LITTLE DESERT',
#  'LODDON VALE',
#  'LOGAN',
#  'LONGWOOD EAST',
#  'LORQUON',
#  'LYONS',
#  'MACKS CREEK',
#  'MACORNA NORTH',
#  'MADALYA',
#  'MAIN LEAD',
#  'MAINTONGOON',
#  'MANORINA',
#  'MARNOO EAST',
#  'MARNOO WEST',
#  'MARRAWEENEY',
#  'MASSEY',
#  'MCINTYRE',
#  'MCMILLANS',
#  'MEADOW CREEK',
#  'MEATIAN',
#  'MELVILLE FOREST',
#  'MELWOOD',
#  'MERRIANG',
#  'MERRINEE',
#  'MIDDLE TARWIN',
#  'MIGA LAKE',
#  'MINGAY',
#  'MINHAMITE',
#  'MINJAH',
#  'MINMINDIE',
#  'MIRRANATWA',
#  'MITTYACK',
#  'MOGLONEMBY',
#  'MOKEPILLY',
#  'MOLKA',
#  'MOLLONGGHIP',
#  'MONGANS BRIDGE',
#  'MOOLERR',
#  'MOONLIGHT FLAT',
#  'MOONLIGHT FLAT',
#  'MOORILIM',
#  'MOORMBOOL WEST',
#  'MOORNAPA',
#  'MORGIANA',
#  'MORRL MORRL',
#  'MORTON PLAINS',
#  'MOUNT ALFRED',
#  'MOUNT BECKWORTH',
#  'MOUNT BOLTON',
#  'MOUNT BRUNO',
#  'MOUNT CAMERON',
#  'MOUNT ECCLES',
#  'MOUNT HOOGHLY',
#  'MOUNT NAPIER',
#  'MOUNT TOOLEBEWONG',
#  'MOYREISK',
#  'MUCKLEFORD SOUTH',
#  'MUNDOONA',
#  'MUNTHAM',
#  'MURMUNGEE',
#  'MURNUNGIN',
#  'MURRAY',
#  'MURRINDAL',
#  'MYWEE',
#  'NANGANA',
#  'NANGEELA',
#  'NAREEB',
#  'NAREEN',
#  'NAREEWILLOCK',
#  'NARINGAL EAST',
#  'NARRAPUMELAP SOUTH',
#  'NARRUNG',
#  'NEDS CORNER',
#  'NEEREMAN',
#  'NEUARPURR',
#  'NEWFIELD',
#  'NINDA',
#  'NINYEUNOOK',
#  'NIRRANDA EAST',
#  'NOORAT EAST',
#  'NOORINBEE NORTH',
#  'NORMANVILLE',
#  'NORTH GEELONG',
#  'NORVAL',
#  'NOWHERE CREEK',
#  'NUG NUG',
#  'NULLAWIL',
#  'NURCOUNG',
#  'NURRAN',
#  'NYARRIN',
#  'NYERIMILANG',
#  'NYRRABY',
#  'OAKVALE',
#  'OLD TALLANGATTA',
#  'OZENKADNOOK',
#  'PAINSWICK',
#  'PASCHENDALE',
#  'PATYAH',
#  'PEECHELBA EAST',
#  'PERONNE',
#  'PICOLA WEST',
#  'PIGEON PONDS',
#  'PIGGOREET',
#  'PINE MOUNTAIN',
#  'PIRA',
#  'PITTONG',
#  'POLISBET',
#  'POMBORNEIT NORTH',
#  'POMONAL',
#  'POWERS CREEK',
#  'PURA PURA',
#  'PURDEET',
#  'PURNIM WEST',
#  'RATHSCAR WEST',
#  'REEDY FLAT',
#  'REEDY LAKE',
#  'RIACHELLA',
#  'RICH AVON',
#  'RICH AVON EAST',
#  'RICH AVON WEST',
#  'RICHMOND PLAINS',
#  'ROCKLANDS',
#  'ROSEBUD WEST',
#  'ROSTRON',
#  'RUFFY',
#  'RUNNING CREEK',
#  'RYANSTON',
#  'SANDHILL LAKE',
#  'SCOTCHMANS LEAD',
#  'SHAYS FLAT',
#  'SHE OAKS',
#  'SIDONIA',
#  'SIMPSONS CREEK',
#  'SPRINGDALLAH',
#  'ST CLAIR',
#  'STAVELY',
#  'STRANGWAYS',
#  'STRATEN',
#  'STRATHKELLAR',
#  'SUTTON',
#  'SWAN BAY',
#  'SWAN HILL WEST',
#  'SWANWATER',
#  'SWANWATER WEST',
#  'TABOR',
#  'TAHARA BRIDGE',
#  'TAHARA WEST',
#  'TAMBOON',
#  'TAMLEUGH',
#  'TAMLEUGH NORTH',
#  'TANDAROOK',
#  'TANJIL BREN',
#  'TANYBRYN',
#  'TARILTA',
#  'TARNOOK',
#  'TARRANYURK',
#  'TARRAWARRA',
#  'TARRAYOUKYAN',
#  'TARRENGOWER',
#  'TARRENLEA',
#  'TARRONE',
#  'TEDDYWADDY WEST',
#  'TELANGATUK EAST',
#  'TERIP TERIP',
#  'TERRAPPEE',
#  'TERRICK TERRICK EAST',
#  'TESBURY',
#  'THALIA',
#  'THE SISTERS',
#  'THOLOGOLONG',
#  'THOONA',
#  'TIMBOON WEST',
#  'TIMOR WEST',
#  'TOOAN',
#  'TOOLONG',
#  'TOTTINGTON',
#  'TOURELLO',
#  'TOWANINNY',
#  'TOWER HILL',
#  'TOWONG',
#  'TOWONG UPPER',
#  'TULKARA',
#  'TURRIFF',
#  'TURRIFF EAST',
#  'TUTYE',
#  'TYENNA',
#  'TYRENDARRA EAST',
#  'TYRRELL',
#  'TYRRELL DOWNS',
#  'ULLINA',
#  'ULLSWATER',
#  'ULTIMA EAST',
#  'UPPER GUNDOWRING',
#  'UPPER LURG',
#  'UPPER RYANS CREEK',
#  'UPTON HILL',
#  'VASEY',
#  'VICTORIA POINT',
#  'VITE VITE NORTH',
#  'W TREE',
#  'WAGGARANDALL',
#  'WAITCHIE',
#  'WAL WAL',
#  'WALKERVILLE NORTH',
#  'WALLUP',
#  'WALMER',
#  'WANDO BRIDGE',
#  'WANGIE',
#  'WARMUR',
#  'WARNE',
#  'WARRABKOOK',
#  'WARROCK',
#  'WATCHEM WEST',
#  'WATERHOLES',
#  'WATTLE HILL',
#  'WEATHERBOARD',
#  'WEEAPROINAH',
#  'WEERING',
#  'WEERITE',
#  'WELLSFORD',
#  'WERONA',
#  'WEST FOOTSCRAY',
#  'WHIRILY',
#  'WHITELAW',
#  'WHOOREL',
#  'WILKUR',
#  'WILLATOOK',
#  'WILLAURA NORTH',
#  'WILLOWVALE',
#  'WILSONS HILL',
#  'WINCHELSEA SOUTH',
#  'WINJALLOK',
#  'WINLATON',
#  'WINNAMBOOL',
#  'WIRRATE',
#  'WOODGLEN',
#  'WOODHOUSE',
#  'WOODSTOCK ON LODDON',
#  'WOOL WOOL',
#  'WOOLENOOK',
#  'WOOLSHED FLAT',
#  'WOORARRA EAST',
#  'WOOREEN',
#  'WOORINEN NORTH',
#  'WULGULMERANG EAST',
#  'WYCHEPROOF SOUTH',
#  'WYCHITELLA NORTH',
#  'YABBA SOUTH',
#  'YALLA',
#  'YANDO',
#  'YANDOIT',
#  'YANDOIT HILLS',
#  'YAPEEN',
#  'YARPTURK',
#  'YARRABERB',
#  'YARRAWONGA SOUTH',
#  'YATCHAW',
#  'YEUNGROON',
#  'YEUNGROON EAST',
#  'YUNDOOL',
#  'YUULONG',
#  'NO USUAL ADDRESS',
#  'MIGRATORY']

# %% [markdown]
# ## 4. Geojson Data

# %%
import json

# %%
geo = open('geojson_simplify2.json')
geo = json.load(geo)
type(geo)
# Out:
# dict

# %%
geo_str = json.dumps(geo)
cr=merge
mel_suburb = list(cr.Suburb)
len(mel_suburb)
# Out:
# 2830

# %%
feature_list = geo['features']
print("There're",len(feature_list),"suburbs included in the geojson data")
# Out:
# There're 2973 suburbs included in the geojson data

# %%
location_dic = {'Suburb':[],'Geometry':[]}
for item in feature_list:
    location_dic['Suburb'].append(item['properties']['vic_loca_2'].title())
    location_dic['Geometry'].append(str(item['geometry']))
suburb_geo = pd.DataFrame(location_dic)
suburb_geo.Suburb=suburb_geo.Suburb.str.upper()
suburb_geo.head()
# Out:
#       Suburb                                           Geometry
# 0  UNDERBOOL  {'type': 'Polygon', 'coordinates': [[[141.7455...
# 1     NURRAN  {'type': 'Polygon', 'coordinates': [[[148.6687...
# 2   WOORNDOO  {'type': 'Polygon', 'coordinates': [[[142.9228...
# 3   DEPTFORD  {'type': 'Polygon', 'coordinates': [[[147.8233...
# 4      YANAC  {'type': 'Polygon', 'coordinates': [[[141.2797...

# %%
suburb_geo.shape
# Out:
# (2973, 2)

# %% [markdown]
# ### Merge CrimeRate and Suburb_geo

# %%
cr.head()
# Out:
#           Suburb  Postcode  OffenceCount  TotPop  CrimeRate
# 0     ABBOTSFORD    3067.0        1478.0    8184     0.1806
# 1     ABERFELDIE    3040.0          97.0    3897     0.0249
# 2        ACHERON    3714.0           5.0     171     0.0292
# 3      ADDINGTON    3352.0           4.0      71     0.0563
# 4  ADELAIDE LEAD    3465.0           3.0      81     0.0370

# %%
result = pd.merge(cr, suburb_geo, on='Suburb', how='inner')
result.head()
# Out:
#           Suburb  Postcode  OffenceCount  TotPop  CrimeRate  \
# 0     ABBOTSFORD    3067.0        1478.0    8184     0.1806
# 1     ABERFELDIE    3040.0          97.0    3897     0.0249
# 2        ACHERON    3714.0           5.0     171     0.0292
# 3      ADDINGTON    3352.0           4.0      71     0.0563
# 4  ADELAIDE LEAD    3465.0           3.0      81     0.0370
#
#                                             Geometry
# 0  {'type': 'Polygon', 'coordinates': [[[144.9913...
# 1  {'type': 'Polygon', 'coordinates': [[[144.9015...
# 2  {'type': 'Polygon', 'coordinates': [[[145.6416...
# 3  {'type': 'Polygon', 'coordinates': [[[143.6572...
# 4  {'type': 'Polygon', 'coordinates': [[[143.7116...

# %%
result.shape
# Out:
# (2868, 6)

# %%
# Delete records with duplicates names
dup_index = result[result.duplicated(['Suburb'])].index
result.drop(index=dup_index,inplace=True)

# %%
result.shape
# Out:
# (2801, 6)

# %%
result[result.isnull().any(axis=1)]
# Out:
#                    Suburb  Postcode  OffenceCount  TotPop  CrimeRate  \
# 2333         ADAMS ESTATE       NaN           NaN      59        NaN
# 2334                AGNES       NaN           NaN      57        NaN
# 2335       ALLAMBEE SOUTH       NaN           NaN      76        NaN
# 2336             ANNUELLO       NaN           NaN      25        NaN
# 2337                APPIN       NaN           NaN      11        NaN
# 2338        ARCHIES CREEK       NaN           NaN      22        NaN
# 2339              AREEGRA       NaN           NaN      35        NaN
# 2340          ARNOLD WEST       NaN           NaN      22        NaN
# 2341               AUBREY       NaN           NaN      10        NaN
# 2342             AVONMORE       NaN           NaN      43        NaN
# 2343            BAEL BAEL       NaN           NaN       8        NaN
# 2344        BAGSHOT NORTH       NaN           NaN      30        NaN
# 2345            BALINTORE       NaN           NaN      67        NaN
# 2346             BALLAPUR       NaN           NaN      10        NaN
# 2347               BALOOK       NaN           NaN       4        NaN
# 2348             BAMGANIE       NaN           NaN      37        NaN
# 2349               BANYAN       NaN           NaN      25        NaN
# 2350       BARINGHUP WEST       NaN           NaN      16        NaN
# 2351               BARKLY       NaN           NaN      43        NaN
# 2352            BARKSTEAD       NaN           NaN      42        NaN
# 2353               BAROMI       NaN           NaN     127        NaN
# 2354       BARRAPORT WEST       NaN           NaN      10        NaN
# 2355       BARUNAH PLAINS       NaN           NaN       9        NaN
# 2356            BARWIDGEE       NaN           NaN     106        NaN
# 2357               BASALT       NaN           NaN      10        NaN
# 2358              BATHUMI       NaN           NaN      62        NaN
# 2359            BAYINDEEN       NaN           NaN      21        NaN
# 2360      BEAZLEYS BRIDGE       NaN           NaN      25        NaN
# 2361               BEENAK       NaN           NaN      25        NaN
# 2362            BELLELLEN       NaN           NaN      57        NaN
# ...                   ...       ...           ...     ...        ...
# 2838     WINCHELSEA SOUTH       NaN           NaN     179        NaN
# 2839            WINJALLOK       NaN           NaN      17        NaN
# 2840             WINLATON       NaN           NaN       7        NaN
# 2841           WINNAMBOOL       NaN           NaN      22        NaN
# 2842              WIRRATE       NaN           NaN       3        NaN
# 2843             WOODGLEN       NaN           NaN      43        NaN
# 2844            WOODHOUSE       NaN           NaN      39        NaN
# 2845  WOODSTOCK ON LODDON       NaN           NaN      28        NaN
# 2846            WOOL WOOL       NaN           NaN      38        NaN
# 2847            WOOLENOOK       NaN           NaN       4        NaN
# 2848        WOOLSHED FLAT       NaN           NaN       3        NaN
# 2849        WOORARRA EAST       NaN           NaN      40        NaN
# 2850              WOOREEN       NaN           NaN      89        NaN
# 2851       WOORINEN NORTH       NaN           NaN      87        NaN
# 2852    WULGULMERANG EAST       NaN           NaN       7        NaN
# 2853     WYCHEPROOF SOUTH       NaN           NaN      12        NaN
# 2854     WYCHITELLA NORTH       NaN           NaN       9        NaN
# 2855          YABBA SOUTH       NaN           NaN      27        NaN
# 2856                YANDO       NaN           NaN      40        NaN
# 2857              YANDOIT       NaN           NaN     154        NaN
# 2858        YANDOIT HILLS       NaN           NaN      28        NaN
# 2859               YAPEEN       NaN           NaN     213        NaN
# 2860             YARPTURK       NaN           NaN      77        NaN
# 2861            YARRABERB       NaN           NaN      23        NaN
# 2862     YARRAWONGA SOUTH       NaN           NaN      15        NaN
# 2863              YATCHAW       NaN           NaN      26        NaN
# 2864            YEUNGROON       NaN           NaN      31        NaN
# 2865       YEUNGROON EAST       NaN           NaN      16        NaN
# 2866              YUNDOOL       NaN           NaN      44        NaN
# 2867              YUULONG       NaN           NaN      37        NaN
#
#                                                Geometry
# 2333  {'type': 'Polygon', 'coordinates': [[[145.5291...
# 2334  {'type': 'Polygon', 'coordinates': [[[146.3995...
# 2335  {'type': 'Polygon', 'coordinates': [[[146.0755...
# 2336  {'type': 'Polygon', 'coordinates': [[[142.9144...
# 2337  {'type': 'Polygon', 'coordinates': [[[143.9185...
# 2338  {'type': 'Polygon', 'coordinates': [[[145.5791...
# 2339  {'type': 'Polygon', 'coordinates': [[[142.7280...
# 2340  {'type': 'Polygon', 'coordinates': [[[143.7965...
# 2341  {'type': 'Polygon', 'coordinates': [[[142.2698...
# 2342  {'type': 'Polygon', 'coordinates': [[[144.4693...
# 2343  {'type': 'Polygon', 'coordinates': [[[143.7731...
# 2344  {'type': 'Polygon', 'coordinates': [[[144.4698...
# 2345  {'type': 'Polygon', 'coordinates': [[[143.5567...
# 2346  {'type': 'Polygon', 'coordinates': [[[142.7968...
# 2347  {'type': 'Polygon', 'coordinates': [[[146.4978...
# 2348  {'type': 'Polygon', 'coordinates': [[[144.0428...
# 2349  {'type': 'Polygon', 'coordinates': [[[142.7934...
# 2350  {'type': 'Polygon', 'coordinates': [[[143.8973...
# 2351  {'type': 'Polygon', 'coordinates': [[[143.1722...
# 2352  {'type': 'Polygon', 'coordinates': [[[144.0831...
# 2353  {'type': 'Polygon', 'coordinates': [[[146.1694...
# 2354  {'type': 'Polygon', 'coordinates': [[[143.5800...
# 2355  {'type': 'Polygon', 'coordinates': [[[143.7522...
# 2356  {'type': 'Polygon', 'coordinates': [[[146.7361...
# 2357  {'type': 'Polygon', 'coordinates': [[[144.1194...
# 2358  {'type': 'Polygon', 'coordinates': [[[146.1014...
# 2359  {'type': 'Polygon', 'coordinates': [[[143.1760...
# 2360  {'type': 'Polygon', 'coordinates': [[[143.2031...
# 2361  {'type': 'Polygon', 'coordinates': [[[145.5890...
# 2362  {'type': 'Polygon', 'coordinates': [[[142.6672...
# ...                                                 ...
# 2838  {'type': 'Polygon', 'coordinates': [[[143.9259...
# 2839  {'type': 'Polygon', 'coordinates': [[[143.1816...
# 2840  {'type': 'Polygon', 'coordinates': [[[143.7089...
# 2841  {'type': 'Polygon', 'coordinates': [[[142.8344...
# 2842  {'type': 'Polygon', 'coordinates': [[[145.0319...
# 2843  {'type': 'Polygon', 'coordinates': [[[147.3620...
# 2844  {'type': 'Polygon', 'coordinates': [[[142.4726...
# 2845  {'type': 'Polygon', 'coordinates': [[[144.0583...
# 2846  {'type': 'Polygon', 'coordinates': [[[143.4611...
# 2847  {'type': 'Polygon', 'coordinates': [[[147.0991...
# 2848  {'type': 'Polygon', 'coordinates': [[[143.6651...
# 2849  {'type': 'Polygon', 'coordinates': [[[146.3658...
# 2850  {'type': 'Polygon', 'coordinates': [[[146.0075...
# 2851  {'type': 'Polygon', 'coordinates': [[[143.4540...
# 2852  {'type': 'Polygon', 'coordinates': [[[148.4123...
# 2853  {'type': 'Polygon', 'coordinates': [[[143.1275...
# 2854  {'type': 'Polygon', 'coordinates': [[[143.6759...
# 2855  {'type': 'Polygon', 'coordinates': [[[145.6314...
# 2856  {'type': 'Polygon', 'coordinates': [[[143.7733...
# 2857  {'type': 'Polygon', 'coordinates': [[[144.1279...
# 2858  {'type': 'Polygon', 'coordinates': [[[144.0650...
# 2859  {'type': 'Polygon', 'coordinates': [[[144.1400...
# 2860  {'type': 'Polygon', 'coordinates': [[[142.4298...
# 2861  {'type': 'Polygon', 'coordinates': [[[144.0143...
# 2862  {'type': 'Polygon', 'coordinates': [[[146.0848...
# 2863  {'type': 'Polygon', 'coordinates': [[[142.1555...
# 2864  {'type': 'Polygon', 'coordinates': [[[143.2856...
# 2865  {'type': 'Polygon', 'coordinates': [[[143.3865...
# 2866  {'type': 'Polygon', 'coordinates': [[[145.8310...
# 2867  {'type': 'Polygon', 'coordinates': [[[143.3630...
#
# [532 rows x 6 columns]

# %%
result.head()
# Out:
#           Suburb  Postcode  OffenceCount  TotPop  CrimeRate  \
# 0     ABBOTSFORD    3067.0        1478.0    8184     0.1806
# 1     ABERFELDIE    3040.0          97.0    3897     0.0249
# 2        ACHERON    3714.0           5.0     171     0.0292
# 3      ADDINGTON    3352.0           4.0      71     0.0563
# 4  ADELAIDE LEAD    3465.0           3.0      81     0.0370
#
#                                             Geometry
# 0  {'type': 'Polygon', 'coordinates': [[[144.9913...
# 1  {'type': 'Polygon', 'coordinates': [[[144.9015...
# 2  {'type': 'Polygon', 'coordinates': [[[145.6416...
# 3  {'type': 'Polygon', 'coordinates': [[[143.6572...
# 4  {'type': 'Polygon', 'coordinates': [[[143.7116...

# %%
result.to_csv('2018CrimeRate_Data.csv',index = False)

# %% [markdown]
# ## Camera Data

# %%
import json
import re

# %%
camera = open('camera.json')
camera = json.load(camera)
type(camera)
# Out:
# list

# %%
camera
# Out:
# [{'attributes': {'FID': 63,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 33: Corner Collins and Exhibition Street',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16138174.729999024, 'y': -4553193.473842271}},
#  {'attributes': {'FID': 64,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 24:Bourke Street Mall',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137372.541319622, 'y': -4553172.357648708}},
#  {'attributes': {'FID': 65,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 4:Bourke Street & King ',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16136404.39053541, 'y': -4553494.078433257}},
#  {'attributes': {'FID': 66,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 29: Corner Queen and Little Collins Street',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137024.27539743, 'y': -4553475.643854935}},
#  {'attributes': {'FID': 67,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera # 50 : Crown Sign on King Street Bridge',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16136661.391479066, 'y': -4554414.624496639}},
#  {'attributes': {'FID': 68,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera # 41 - Corner Flinders La/Staughton Ally',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137331.243454684, 'y': -4553642.474956827}},
#  {'attributes': {'FID': 69,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera # 44: Cnr Spencer St/Lonsdale St',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16136041.058300111, 'y': -4553354.376073021}},
#  {'attributes': {'FID': 70,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 12:Little Bourke Street & Russell Street ',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137744.928419832, 'y': -4552877.137787356}},
#  {'attributes': {'FID': 71,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera # 47: Corner Latrobe St/ Harbour Esp',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16135152.46435912, 'y': -4553349.699557835}},
#  {'attributes': {'FID': 72,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Camera 56: Spencer St (Batman Park)',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16136409.938047428, 'y': -4554366.962490682}},
#  {'attributes': {'FID': 73,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 13:Flinders Lane & Swanston Street ',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137666.486989211, 'y': -4553527.402085189}},
#  {'attributes': {'FID': 74,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 37: Corner Latrobe and Swanston Street',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137298.767333675, 'y': -4552580.536196185}},
#  {'attributes': {'FID': 75,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 26: Corner Finders Lane and Elizabeth Street',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137385.515238447, 'y': -4553617.604364126}},
#  {'attributes': {'FID': 76,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera # 53: Riverside/St Kilds Road Bridge',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137776.42384138, 'y': -4554006.31504649}},
#  {'attributes': {'FID': 77,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 17:Little Collins Street & Swanston Street ',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137550.39045123, 'y': -4553283.461394682}},
#  {'attributes': {'FID': 78,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera # 48: Harbour ESP SE Corner West Wharf',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16135104.8847056, 'y': -4553205.802324943}},
#  {'attributes': {'FID': 79,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City Camera # 38 -Latrobe and Elizabeth',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137027.483430428, 'y': -4552642.00737587}},
#  {'attributes': {'FID': 80,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 7:Outside 55 King Street ',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16136513.647786556, 'y': -4553869.145091211}},
#  {'attributes': {'FID': 81,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera # 40: Corner Latrobe/William',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16136492.045349946, 'y': -4552843.559468073}},
#  {'attributes': {'FID': 82,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 11:Bourke Street & Russell Street ',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137794.45285222, 'y': -4553025.696233607}},
#  {'attributes': {'FID': 83,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 14:Flinders Street Station steps ',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137704.59897246, 'y': -4553700.826806094}},
#  {'attributes': {'FID': 84,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 22:Flinders Street & Elizabeth Street ',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137418.14529157, 'y': -4553790.530626546}},
#  {'attributes': {'FID': 85,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera # 46: Harbour Esp SE Crn Center Wharf',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16135154.73119652, 'y': -4553481.701798703}},
#  {'attributes': {'FID': 86,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 16:Flinders Street & Swanston Street ',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137729.423357686, 'y': -4553679.209352756}},
#  {'attributes': {'FID': 87,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 6:Collins Street & King Street ',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16136518.10845721, 'y': -4553809.505893983}},
#  {'attributes': {'FID': 88,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 5:Little Collins Street & King Street ',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16136430.7704675, 'y': -4553648.391113127}},
#  {'attributes': {'FID': 89,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 19:Bourke Street & Swanston Street ',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137508.075942598, 'y': -4553102.840058785}},
#  {'attributes': {'FID': 90,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera # 49: Clarendon Street Opposite Convention Center',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16136476.389329562, 'y': -4554554.756974554}},
#  {'attributes': {'FID': 91,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 28: Corner Queen and Flinders Street',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137122.93162183, 'y': -4553867.615389965}},
#  {'attributes': {'FID': 92,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 1:Lonsdale Street & King Street ',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16136277.049440913, 'y': -4553229.610730087}},
#  {'attributes': {'FID': 93,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 34: Corner Spring and Collins (VicRoads Pole)',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16138435.897954496, 'y': -4553070.301714512}},
#  {'attributes': {'FID': 94,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera # 43: Corner Spencer St/ Bourke St',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16136128.397164064, 'y': -4553597.35923663}},
#  {'attributes': {'FID': 95,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 30: Corner Queen and Bourke Street',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16136918.165861366, 'y': -4553313.974427878}},
#  {'attributes': {'FID': 96,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 3:Little Bourke Street & King Street ',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16136327.131778922, 'y': -4553381.850385955}},
#  {'attributes': {'FID': 97,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 20:Bourke Street & Elizabeth Street ',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137211.13050339, 'y': -4553234.399298244}},
#  {'attributes': {'FID': 98,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Camera 60: Williams and Flinders St (South)',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16136889.563923594, 'y': -4553941.896095587}},
#  {'attributes': {'FID': 99,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Camera 61: North Bank, Flinders Walk',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137440.581846802, 'y': -4553913.9884845475}},
#  {'attributes': {'FID': 100,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe city camera #39 - Lonsdale/Hardware Lane',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16136958.23859933, 'y': -4553020.249465859}},
#  {'attributes': {'FID': 101,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 8:Flinders Lane & King Street ',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16136529.759390444, 'y': -4553943.434411943}},
#  {'attributes': {'FID': 102,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera # 55',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16136915.193714706, 'y': -4553169.184259648}},
#  {'attributes': {'FID': 103,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 2:Outside 212 King Street ',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16136342.52664059, 'y': -4553325.336991819}},
#  {'attributes': {'FID': 104,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 27: Corner Flinders Street and Russell Street',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16138002.740970548, 'y': -4553547.0379728675}},
#  {'attributes': {'FID': 105,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 9:Flinders Street & King Street ',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16136594.910826365, 'y': -4554066.043337832}},
#  {'attributes': {'FID': 106,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera # 51: Southbank Prom & Queen Brdg Square',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137066.208626917, 'y': -4554187.338860728}},
#  {'attributes': {'FID': 107,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 1600:Taxi Rank Outside Flinders Street Station.',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137697.708721897, 'y': -4553806.371256415}},
#  {'attributes': {'FID': 108,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 23:Collins Street & Elizabeth Street ',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137340.772404391, 'y': -4553476.11193902}},
#  {'attributes': {'FID': 109,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera # 45: Harbour Esp NW Nab Building',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16135369.049916407, 'y': -4553939.118842232}},
#  {'attributes': {'FID': 110,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Camera 63: Southgate Ave and Southbank Junction',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137439.219601812, 'y': -4554055.468358485}},
#  {'attributes': {'FID': 111,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 700:Taxi Rank Outside 55 King Street.',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16136551.469172744, 'y': -4553905.864062681}},
#  {'attributes': {'FID': 112,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 31: Corner Collins and Russell Street',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137878.992500717, 'y': -4553267.161498813}},
#  {'attributes': {'FID': 113,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 36: Corner Exhbition and Lonsdale Street',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137953.890919438, 'y': -4552613.964435455}},
#  {'attributes': {'FID': 114,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera # 52: Les Erdi Plaza/Nthbank ',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137210.13340116, 'y': -4554015.199953386}},
#  {'attributes': {'FID': 115,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Camera 59: Williams and Flinders St (West)',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16136889.728245534, 'y': -4553941.8996994095}},
#  {'attributes': {'FID': 116,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 1800:Taxi Rank 40 Bourke Street.',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16138244.187315652, 'y': -4552829.16382863}},
#  {'attributes': {'FID': 117,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 21:Little Lonsdale Street & Swanston Street ',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137370.270292716, 'y': -4552700.673011511}},
#  {'attributes': {'FID': 118,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 15:Lonsdale Street & Russell Street ',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137654.24843231, 'y': -4552725.586762189}},
#  {'attributes': {'FID': 119,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 25 Corner Swanston and Collins Street',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137620.09598476, 'y': -4553420.365748129}},
#  {'attributes': {'FID': 120,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera # 42: Corner Flinders St/Spencer St',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16136336.81012873, 'y': -4554158.361887538}},
#  {'attributes': {'FID': 121,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 35: Corner Exhibition and Bourke Street',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16138055.90292496, 'y': -4552888.904050164}},
#  {'attributes': {'FID': 122,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 32: Corner Lonsdale and Swanston Street',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16137397.8674393, 'y': -4552874.642314247}},
#  {'attributes': {'FID': 123,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera 18:Bourke Street & Spring Street ',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16138267.931313893, 'y': -4552826.963961117}},
#  {'attributes': {'FID': 124,
#    'OBJECTID': None,
#    'MCC_ID': None,
#    'STR_ID': None,
#    'ASSET_CLAS': None,
#    'Title': 'Safe City Camera',
#    'ASSET_SUBT': None,
#    'Location': 'Security - Safe City - Camera # 54: Birranrung Marr',
#    'MODEL_NO': None,
#    'MODEL_DESC': None,
#    'Content': '',
#    'PROP_ID': None,
#    'ROADSEG_ID': None,
#    'ADDRESSPT_': None,
#    'ADDRESSPT1': None,
#    'ADDRESSP_1': None},
#   'geometry': {'x': 16138261.56619788, 'y': -4553833.459747885}}]

# %%
list(camera[0]['geometry'].values())
# Out:
# [16138174.729999024, -4553193.473842271]

# %%
camera_list = []
for record in camera:
    camera_list.append(record['geometry'])
camera_dic['']
# Out:
# 62

# %%
st = []
for record in camera:
    st.append(record['attributes']['Location'])
for i in range(len(st)):
    st[i]=re.sub(r'Security - Safe City - Camera [#\d -:]*','',st[i])
    st[i]=re.sub(r'Camera [#\d -:]*','',st[i])
    st[i]=st[i].strip(' ')
st.remove('')
st
# Out:
# ['Corner Collins and Exhibition Street',
#  'Bourke Street Mall',
#  'Bourke Street & King',
#  'Corner Queen and Little Collins Street',
#  'Crown Sign on King Street Bridge',
#  'Corner Flinders La/Staughton Ally',
#  'Cnr Spencer St/Lonsdale St',
#  'Little Bourke Street & Russell Street',
#  'Corner Latrobe St/ Harbour Esp',
#  'Spencer St (Batman Park)',
#  'Flinders Lane & Swanston Street',
#  'Corner Latrobe and Swanston Street',
#  'Corner Finders Lane and Elizabeth Street',
#  'Riverside/St Kilds Road Bridge',
#  'Little Collins Street & Swanston Street',
#  'Harbour ESP SE Corner West Wharf',
#  'Security - Safe City Latrobe and Elizabeth',
#  'Outside 55 King Street',
#  'Corner Latrobe/William',
#  'Bourke Street & Russell Street',
#  'Flinders Street Station steps',
#  'Flinders Street & Elizabeth Street',
#  'Harbour Esp SE Crn Center Wharf',
#  'Flinders Street & Swanston Street',
#  'Collins Street & King Street',
#  'Little Collins Street & King Street',
#  'Bourke Street & Swanston Street',
#  'Clarendon Street Opposite Convention Center',
#  'Corner Queen and Flinders Street',
#  'Lonsdale Street & King Street',
#  'Corner Spring and Collins (VicRoads Pole)',
#  'Corner Spencer St/ Bourke St',
#  'Corner Queen and Bourke Street',
#  'Little Bourke Street & King Street',
#  'Bourke Street & Elizabeth Street',
#  'Williams and Flinders St (South)',
#  'North Bank, Flinders Walk',
#  'Security - Safe city camera #39 - Lonsdale/Hardware Lane',
#  'Flinders Lane & King Street',
#  'Outside 212 King Street',
#  'Corner Flinders Street and Russell Street',
#  'Flinders Street & King Street',
#  'Southbank Prom & Queen Brdg Square',
#  'Taxi Rank Outside Flinders Street Station.',
#  'Collins Street & Elizabeth Street',
#  'Harbour Esp NW Nab Building',
#  'Southgate Ave and Southbank Junction',
#  'Taxi Rank Outside 55 King Street.',
#  'Corner Collins and Russell Street',
#  'Corner Exhbition and Lonsdale Street',
#  'Les Erdi Plaza/Nthbank',
#  'Williams and Flinders St (West)',
#  'Taxi Rank 40 Bourke Street.',
#  'Little Lonsdale Street & Swanston Street',
#  'Lonsdale Street & Russell Street',
#  'Corner Swanston and Collins Street',
#  'Corner Flinders St/Spencer St',
#  'Corner Exhibition and Bourke Street',
#  'Corner Lonsdale and Swanston Street',
#  'Bourke Street & Spring Street',
#  'Birranrung Marr']

# %%
len(st)
# Out:
# 61

# %%
for i in range(len(st)):
    st[i]=re.sub(r'Corner','',st[i])
    st[i]=re.sub(r'Outside','',st[i])
    st[i] = st[i].strip(' ')
st
# Out:
# ['Collins and Exhibition Street',
#  'Bourke Street Mall',
#  'Bourke Street & King',
#  'Queen and Little Collins Street',
#  'Crown Sign on King Street Bridge',
#  'Flinders La/Staughton Ally',
#  'Cnr Spencer St/Lonsdale St',
#  'Little Bourke Street & Russell Street',
#  'Latrobe St/ Harbour Esp',
#  'Spencer St (Batman Park)',
#  'Flinders Lane & Swanston Street',
#  'Latrobe and Swanston Street',
#  'Finders Lane and Elizabeth Street',
#  'Riverside/St Kilds Road Bridge',
#  'Little Collins Street & Swanston Street',
#  'Harbour ESP SE  West Wharf',
#  'Security - Safe City Latrobe and Elizabeth',
#  '55 King Street',
#  'Latrobe/William',
#  'Bourke Street & Russell Street',
#  'Flinders Street Station steps',
#  'Flinders Street & Elizabeth Street',
#  'Harbour Esp SE Crn Center Wharf',
#  'Flinders Street & Swanston Street',
#  'Collins Street & King Street',
#  'Little Collins Street & King Street',
#  'Bourke Street & Swanston Street',
#  'Clarendon Street Opposite Convention Center',
#  'Queen and Flinders Street',
#  'Lonsdale Street & King Street',
#  'Spring and Collins (VicRoads Pole)',
#  'Spencer St/ Bourke St',
#  'Queen and Bourke Street',
#  'Little Bourke Street & King Street',
#  'Bourke Street & Elizabeth Street',
#  'Williams and Flinders St (South)',
#  'North Bank, Flinders Walk',
#  'Security - Safe city camera #39 - Lonsdale/Hardware Lane',
#  'Flinders Lane & King Street',
#  '212 King Street',
#  'Flinders Street and Russell Street',
#  'Flinders Street & King Street',
#  'Southbank Prom & Queen Brdg Square',
#  'Taxi Rank  Flinders Street Station.',
#  'Collins Street & Elizabeth Street',
#  'Harbour Esp NW Nab Building',
#  'Southgate Ave and Southbank Junction',
#  'Taxi Rank  55 King Street.',
#  'Collins and Russell Street',
#  'Exhbition and Lonsdale Street',
#  'Les Erdi Plaza/Nthbank',
#  'Williams and Flinders St (West)',
#  'Taxi Rank 40 Bourke Street.',
#  'Little Lonsdale Street & Swanston Street',
#  'Lonsdale Street & Russell Street',
#  'Swanston and Collins Street',
#  'Flinders St/Spencer St',
#  'Exhibition and Bourke Street',
#  'Lonsdale and Swanston Street',
#  'Bourke Street & Spring Street',
#  'Birranrung Marr']

# %% [markdown]
# ## Street Light Data

# %%
import json
light = open('StreetLight.geojson')
light = json.load(light)
type(light)
# Out:
# dict

# %%
light = light['features']
len(light)
# Out:
# 106037

# %%
result = []
for i in range(len(light)):
    temp = []
    temp.append(light[i]['geometry']['coordinates'][1])
    temp.append(light[i]['geometry']['coordinates'][0])
    temp.append(light[i]['properties']['label'])
    result.append(temp)

# %%
len(result)
# Out:
# 106037

# %% [markdown]
# #### Streelight Shorten V1 1/10

# %%
# Shorten version 1
short1 = []
for i in range(len(result)):
    if i%10 == 0:
        short1.append(result[i])
short_json = []
for record in short1:
    temp = {}
    temp['lat'] = round(record[0],6)
    temp['log'] = round(record[1],6)
    temp['lux'] = float(record[2])
    short_json.append(temp)
short_json = json.dumps(short_json)
file = open('LightLocation_short1.json','w')
file.write(short_json)
file.close()

# %%
len(short1)
# Out:
# 10604

# %% [markdown]
# #### Streetlight Shorten V2 1/100

# %%
# Shorten version 1
short2 = []
for i in range(len(result)):
    if i%100 == 0:
        short2.append(result[i])
short_json = []
for record in short2:
    temp = {}
    temp['lat'] = round(record[0],6)
    temp['log'] = round(record[1],6)
    temp['lux'] = float(record[2])
    short_json.append(temp)
short_json = json.dumps(short_json)
file = open('LightLocation_short2.json','w')
file.write(short_json)
file.close()

# %%
len(short2)
# Out:
# 1061

# %%
result_json = []
for record in result:
    temp = {}
    temp['lat'] = round(record[0],6)
    temp['log'] = round(record[1],6)
    temp['lux'] = float(record[2])
    result_json.append(temp)
result_json = json.dumps(result_json)
file = open('LightLocation.json','w')
file.write(result_json)
file.close()
# Out:
# [{'lat': -37.813739, 'log': 144.942129, 'lux': 6.549},
#  {'lat': -37.813744, 'log': 144.942139, 'lux': 6.158},
#  {'lat': -37.813803, 'log': 144.94222, 'lux': 54.448},
#  {'lat': -37.813805, 'log': 144.942225, 'lux': 58.553},
#  {'lat': -37.81381, 'log': 144.94224, 'lux': 98.143},
#  {'lat': -37.813816, 'log': 144.942253, 'lux': 97.165},
#  {'lat': -37.813515, 'log': 144.941788, 'lux': 21.799},
#  {'lat': -37.813519, 'log': 144.941793, 'lux': 18.28},
#  {'lat': -37.813556, 'log': 144.941821, 'lux': 23.754},
#  {'lat': -37.813566, 'log': 144.941828, 'lux': 34.409},
#  {'lat': -37.813578, 'log': 144.941845, 'lux': 45.943},
#  {'lat': -37.813619, 'log': 144.941913, 'lux': 2.542},
#  {'lat': -37.813636, 'log': 144.941945, 'lux': 2.151},
#  {'lat': -37.813637, 'log': 144.941948, 'lux': 2.151},
#  {'lat': -37.813643, 'log': 144.941961, 'lux': 3.812},
#  {'lat': -37.81365, 'log': 144.941973, 'lux': 9.58},
#  {'lat': -37.813651, 'log': 144.941976, 'lux': 13.099},
#  {'lat': -37.813658, 'log': 144.941987, 'lux': 27.37},
#  {'lat': -37.813666, 'log': 144.941999, 'lux': 36.461},
#  {'lat': -37.813671, 'log': 144.942013, 'lux': 43.988},
#  {'lat': -37.813684, 'log': 144.94205, 'lux': 41.838},
#  {'lat': -37.813723, 'log': 144.942101, 'lux': 8.895},
#  {'lat': -37.81373, 'log': 144.942111, 'lux': 6.843},
#  {'lat': -37.813829, 'log': 144.942278, 'lux': 68.231},
#  {'lat': -37.813836, 'log': 144.942292, 'lux': 62.659},
#  {'lat': -37.813847, 'log': 144.942313, 'lux': 24.242},
#  {'lat': -37.813852, 'log': 144.942322, 'lux': 22.581},
#  {'lat': -37.813911, 'log': 144.942383, 'lux': 99.316},
#  {'lat': -37.813923, 'log': 144.942406, 'lux': 85.533},
#  {'lat': -37.813928, 'log': 144.942416, 'lux': 59.726},
#  {'lat': -37.813939, 'log': 144.942434, 'lux': 47.019},
#  {'lat': -37.813402, 'log': 144.941696, 'lux': 13.294},
#  {'lat': -37.81343, 'log': 144.941717, 'lux': 24.536},
#  {'lat': -37.813442, 'log': 144.941727, 'lux': 26.784},
#  {'lat': -37.813444, 'log': 144.941728, 'lux': 27.175},
#  {'lat': -37.81346, 'log': 144.941737, 'lux': 25.024},
#  {'lat': -37.81349, 'log': 144.941762, 'lux': 35.484},
#  {'lat': -37.81408, 'log': 144.942792, 'lux': 99.316},
#  {'lat': -37.814076, 'log': 144.942795, 'lux': 99.316},
#  {'lat': -37.814075, 'log': 144.942795, 'lux': 99.316},
#  {'lat': -37.814075, 'log': 144.942795, 'lux': 99.316},
#  {'lat': -37.802293, 'log': 144.965908, 'lux': 1.857},
#  {'lat': -37.802292, 'log': 144.965917, 'lux': 0.782},
#  {'lat': -37.802292, 'log': 144.965919, 'lux': 0.587},
#  {'lat': -37.802292, 'log': 144.965922, 'lux': 0.489},
#  {'lat': -37.802555, 'log': 144.965886, 'lux': 3.715},
#  {'lat': -37.802552, 'log': 144.965843, 'lux': 4.106},
#  {'lat': -37.80255, 'log': 144.965823, 'lux': 5.083},
#  {'lat': -37.802539, 'log': 144.965772, 'lux': 10.362},
#  {'lat': -37.802528, 'log': 144.965744, 'lux': 15.445},
#  {'lat': -37.802527, 'log': 144.965743, 'lux': 15.445},
#  {'lat': -37.802523, 'log': 144.965739, 'lux': 14.761},
#  {'lat': -37.802518, 'log': 144.965736, 'lux': 13.685},
#  {'lat': -37.813963, 'log': 144.942477, 'lux': 4.106},
#  {'lat': -37.813975, 'log': 144.942497, 'lux': 5.279},
#  {'lat': -37.813977, 'log': 144.9425, 'lux': 6.061},
#  {'lat': -37.814007, 'log': 144.942543, 'lux': 18.768},
#  {'lat': -37.814026, 'log': 144.942585, 'lux': 14.663},
#  {'lat': -37.814049, 'log': 144.942642, 'lux': 2.542},
#  {'lat': -37.814052, 'log': 144.942649, 'lux': 2.346},
#  {'lat': -37.814062, 'log': 144.942669, 'lux': 3.324},
#  {'lat': -37.814065, 'log': 144.942675, 'lux': 4.399},
#  {'lat': -37.814076, 'log': 144.942696, 'lux': 12.023},
#  {'lat': -37.814082, 'log': 144.942708, 'lux': 24.829},
#  {'lat': -37.814084, 'log': 144.942713, 'lux': 39.101},
#  {'lat': -37.814091, 'log': 144.942753, 'lux': 99.316},
#  {'lat': -37.814091, 'log': 144.942755, 'lux': 99.316},
#  {'lat': -37.814089, 'log': 144.942769, 'lux': 99.316},
#  {'lat': -37.802511, 'log': 144.96573, 'lux': 10.362},
#  {'lat': -37.802494, 'log': 144.965719, 'lux': 9.677},
#  {'lat': -37.80249, 'log': 144.965716, 'lux': 10.264},
#  {'lat': -37.802484, 'log': 144.965712, 'lux': 11.241},
#  {'lat': -37.802481, 'log': 144.965711, 'lux': 11.73},
#  {'lat': -37.80244, 'log': 144.965698, 'lux': 15.836},
#  {'lat': -37.802438, 'log': 144.965698, 'lux': 16.031},
#  {'lat': -37.802429, 'log': 144.965698, 'lux': 15.445},
#  {'lat': -37.8024, 'log': 144.965698, 'lux': 20.039},
#  {'lat': -37.802392, 'log': 144.965698, 'lux': 21.31},
#  {'lat': -37.802382, 'log': 144.965698, 'lux': 19.55},
#  {'lat': -37.802299, 'log': 144.965954, 'lux': 0.782},
#  {'lat': -37.802299, 'log': 144.965956, 'lux': 0.587},
#  {'lat': -37.802303, 'log': 144.965973, 'lux': 2.053},
#  {'lat': -37.802307, 'log': 144.965988, 'lux': 0.587},
#  {'lat': -37.80232, 'log': 144.966036, 'lux': 8.113},
#  {'lat': -37.802334, 'log': 144.966071, 'lux': 19.355},
#  {'lat': -37.802368, 'log': 144.96611, 'lux': 10.85},
#  {'lat': -37.802386, 'log': 144.96611, 'lux': 8.309},
#  {'lat': -37.80243, 'log': 144.96611, 'lux': 3.715},
#  {'lat': -37.802442, 'log': 144.96611, 'lux': 3.91},
#  {'lat': -37.802456, 'log': 144.96611, 'lux': 4.985},
#  {'lat': -37.802458, 'log': 144.96611, 'lux': 4.888},
#  {'lat': -37.802497, 'log': 144.9661, 'lux': 5.865},
#  {'lat': -37.802516, 'log': 144.966088, 'lux': 7.722},
#  {'lat': -37.802525, 'log': 144.966082, 'lux': 8.7},
#  {'lat': -37.802538, 'log': 144.966064, 'lux': 10.264},
#  {'lat': -37.802549, 'log': 144.966044, 'lux': 17.009},
#  {'lat': -37.802555, 'log': 144.966029, 'lux': 18.377},
#  {'lat': -37.802556, 'log': 144.966026, 'lux': 17.595},
#  {'lat': -37.802561, 'log': 144.965992, 'lux': 8.309},
#  {'lat': -37.802562, 'log': 144.965977, 'lux': 6.745},
#  {'lat': -37.802562, 'log': 144.965967, 'lux': 5.963},
#  {'lat': -37.802561, 'log': 144.965959, 'lux': 5.67},
#  {'lat': -37.80256, 'log': 144.965953, 'lux': 5.474},
#  {'lat': -37.80256, 'log': 144.965951, 'lux': 5.279},
#  {'lat': -37.802558, 'log': 144.965927, 'lux': 4.399},
#  {'lat': -37.802557, 'log': 144.965923, 'lux': 4.301},
#  {'lat': -37.802556, 'log': 144.965912, 'lux': 4.106},
#  {'lat': -37.803075, 'log': 144.965818, 'lux': 16.129},
#  {'lat': -37.803062, 'log': 144.965805, 'lux': 8.993},
#  {'lat': -37.803049, 'log': 144.965791, 'lux': 5.67},
#  {'lat': -37.803036, 'log': 144.965772, 'lux': 8.113},
#  {'lat': -37.803025, 'log': 144.965756, 'lux': 11.241},
#  {'lat': -37.803017, 'log': 144.965749, 'lux': 8.504},
#  {'lat': -37.803011, 'log': 144.965741, 'lux': 11.339},
#  {'lat': -37.80301, 'log': 144.965739, 'lux': 11.144},
#  {'lat': -37.803008, 'log': 144.965736, 'lux': 11.046},
#  {'lat': -37.80299, 'log': 144.96571, 'lux': 5.67},
#  {'lat': -37.802242, 'log': 144.965927, 'lux': 0.391},
#  {'lat': -37.803374, 'log': 144.966248, 'lux': 2.248},
#  {'lat': -37.803374, 'log': 144.966248, 'lux': 2.151},
#  {'lat': -37.803353, 'log': 144.966227, 'lux': 0.88},
#  {'lat': -37.803351, 'log': 144.966224, 'lux': 0.88},
#  {'lat': -37.803342, 'log': 144.96621, 'lux': 0.098},
#  {'lat': -37.803339, 'log': 144.966205, 'lux': 0.098},
#  {'lat': -37.803337, 'log': 144.966202, 'lux': 0.391},
#  {'lat': -37.803321, 'log': 144.966189, 'lux': 1.271},
#  {'lat': -37.803286, 'log': 144.966152, 'lux': 3.519},
#  {'lat': -37.803285, 'log': 144.96615, 'lux': 3.617},
#  {'lat': -37.80298, 'log': 144.9657, 'lux': 2.346},
#  {'lat': -37.802975, 'log': 144.965693, 'lux': 1.662},
#  {'lat': -37.802964, 'log': 144.965675, 'lux': 1.173},
#  {'lat': -37.802959, 'log': 144.965668, 'lux': 0.782},
#  {'lat': -37.802952, 'log': 144.965658, 'lux': 0.684},
#  {'lat': -37.80294, 'log': 144.965642, 'lux': 0.196},
#  {'lat': -37.802922, 'log': 144.965609, 'lux': 0.489},
#  {'lat': -37.802917, 'log': 144.965599, 'lux': 0.293},
#  {'lat': -37.802907, 'log': 144.965584, 'lux': 0.587},
#  {'lat': -37.802901, 'log': 144.965572, 'lux': 0.587},
#  {'lat': -37.802329, 'log': 144.965731, 'lux': 12.61},
#  {'lat': -37.802325, 'log': 144.965741, 'lux': 11.046},
#  {'lat': -37.802319, 'log': 144.96579, 'lux': 11.437},
#  {'lat': -37.802323, 'log': 144.965808, 'lux': 10.753},
#  {'lat': -37.802324, 'log': 144.96581, 'lux': 10.459},
#  {'lat': -37.802324, 'log': 144.965813, 'lux': 10.459},
#  {'lat': -37.802326, 'log': 144.96582, 'lux': 9.189},
#  {'lat': -37.803265, 'log': 144.966116, 'lux': 1.369},
#  {'lat': -37.803234, 'log': 144.966067, 'lux': 0.196},
#  {'lat': -37.803218, 'log': 144.966043, 'lux': 0.293},
#  {'lat': -37.803193, 'log': 144.966009, 'lux': 0.391},
#  {'lat': -37.803179, 'log': 144.965986, 'lux': 1.662},
#  {'lat': -37.803171, 'log': 144.965973, 'lux': 1.662},
#  {'lat': -37.803166, 'log': 144.965965, 'lux': 1.76},
#  {'lat': -37.80232, 'log': 144.965876, 'lux': 4.399},
#  {'lat': -37.802319, 'log': 144.965879, 'lux': 4.301},
#  {'lat': -37.80231, 'log': 144.96589, 'lux': 4.106},
#  {'lat': -37.802292, 'log': 144.965906, 'lux': 0.684},
#  {'lat': -37.802291, 'log': 144.965907, 'lux': 0.684},
#  {'lat': -37.802268, 'log': 144.965912, 'lux': 0.293},
#  {'lat': -37.803157, 'log': 144.965947, 'lux': 1.857},
#  {'lat': -37.803148, 'log': 144.96593, 'lux': 3.421},
#  {'lat': -37.803139, 'log': 144.965919, 'lux': 7.234},
#  {'lat': -37.803126, 'log': 144.965898, 'lux': 25.318},
#  {'lat': -37.803123, 'log': 144.96589, 'lux': 32.454},
#  {'lat': -37.803117, 'log': 144.965878, 'lux': 44.77},
#  {'lat': -37.803102, 'log': 144.965854, 'lux': 64.223},
#  {'lat': -37.803091, 'log': 144.965838, 'lux': 42.131},
#  {'lat': -37.803089, 'log': 144.965836, 'lux': 36.852},
#  {'lat': -37.802646, 'log': 144.965332, 'lux': 33.236},
#  {'lat': -37.802646, 'log': 144.965332, 'lux': 33.236},
#  {'lat': -37.802647, 'log': 144.965329, 'lux': 31.965},
#  {'lat': -37.802648, 'log': 144.965327, 'lux': 31.085},
#  {'lat': -37.802649, 'log': 144.965324, 'lux': 30.303},
#  {'lat': -37.802656, 'log': 144.965317, 'lux': 30.987},
#  {'lat': -37.802659, 'log': 144.965317, 'lux': 31.085},
#  {'lat': -37.802661, 'log': 144.965317, 'lux': 30.694},
#  {'lat': -37.802662, 'log': 144.965304, 'lux': 30.694},
#  {'lat': -37.802663, 'log': 144.965306, 'lux': 30.694},
#  {'lat': -37.802664, 'log': 144.965308, 'lux': 30.694},
#  {'lat': -37.802753, 'log': 144.966074, 'lux': 16.911},
#  {'lat': -37.802756, 'log': 144.9661, 'lux': 14.663},
#  {'lat': -37.818635, 'log': 144.949463, 'lux': 25.904},
#  {'lat': -37.818638, 'log': 144.949463, 'lux': 26.002},
#  {'lat': -37.818644, 'log': 144.949463, 'lux': 28.641},
#  {'lat': -37.818708, 'log': 144.949463, 'lux': 40.469},
#  {'lat': -37.802869, 'log': 144.965508, 'lux': 1.075},
#  {'lat': -37.802835, 'log': 144.965443, 'lux': 0.88},
#  {'lat': -37.802826, 'log': 144.965432, 'lux': 1.173},
#  {'lat': -37.802817, 'log': 144.965421, 'lux': 1.075},
#  {'lat': -37.802803, 'log': 144.965393, 'lux': 3.128},
#  {'lat': -37.802789, 'log': 144.965384, 'lux': 3.421},
#  {'lat': -37.802768, 'log': 144.965353, 'lux': 6.158},
#  {'lat': -37.802762, 'log': 144.965345, 'lux': 7.234},
#  {'lat': -37.802752, 'log': 144.965335, 'lux': 9.775},
#  {'lat': -37.802745, 'log': 144.965328, 'lux': 11.926},
#  {'lat': -37.802739, 'log': 144.965323, 'lux': 13.294},
#  {'lat': -37.802718, 'log': 144.965307, 'lux': 19.648},
#  {'lat': -37.802713, 'log': 144.965303, 'lux': 22.287},
#  {'lat': -37.802675, 'log': 144.965312, 'lux': 31.867},
#  {'lat': -37.80267, 'log': 144.965317, 'lux': 32.258},
#  {'lat': -37.802662, 'log': 144.965317, 'lux': 30.401},
#  {'lat': -37.802658, 'log': 144.965317, 'lux': 31.672},
#  {'lat': -37.802653, 'log': 144.965319, 'lux': 32.356},
#  {'lat': -37.802649, 'log': 144.965328, 'lux': 33.138},
#  {'lat': -37.818732, 'log': 144.949463, 'lux': 34.604},
#  {'lat': -37.818736, 'log': 144.949463, 'lux': 33.04},
#  {'lat': -37.818741, 'log': 144.949463, 'lux': 30.987},
#  {'lat': -37.818745, 'log': 144.949463, 'lux': 27.957},
#  {'lat': -37.818752, 'log': 144.949463, 'lux': 23.069},
#  {'lat': -37.818756, 'log': 144.949463, 'lux': 19.257},
#  {'lat': -37.81881, 'log': 144.949493, 'lux': 7.918},
#  {'lat': -37.802665, 'log': 144.965314, 'lux': 29.619},
#  {'lat': -37.802666, 'log': 144.96532, 'lux': 28.739},
#  {'lat': -37.802673, 'log': 144.965354, 'lux': 34.702},
#  {'lat': -37.802678, 'log': 144.965373, 'lux': 28.055},
#  {'lat': -37.80268, 'log': 144.965383, 'lux': 31.378},
#  {'lat': -37.802686, 'log': 144.965454, 'lux': 8.113},
#  {'lat': -37.802689, 'log': 144.965488, 'lux': 4.301},
#  {'lat': -37.802703, 'log': 144.965591, 'lux': 22.483},
#  {'lat': -37.802703, 'log': 144.965602, 'lux': 18.28},
#  {'lat': -37.80272, 'log': 144.965707, 'lux': 14.174},
#  {'lat': -37.802722, 'log': 144.965724, 'lux': 28.935},
#  {'lat': -37.802728, 'log': 144.965786, 'lux': 32.649},
#  {'lat': -37.802736, 'log': 144.965864, 'lux': 4.497},
#  {'lat': -37.802737, 'log': 144.965871, 'lux': 5.963},
#  {'lat': -37.802741, 'log': 144.965904, 'lux': 14.956},
#  {'lat': -37.802742, 'log': 144.965919, 'lux': 21.505},
#  {'lat': -37.802744, 'log': 144.965969, 'lux': 14.761},
#  {'lat': -37.802751, 'log': 144.96603, 'lux': 4.497},
#  {'lat': -37.820003, 'log': 144.950798, 'lux': 1.955},
#  {'lat': -37.820061, 'log': 144.950851, 'lux': 2.053},
#  {'lat': -37.820112, 'log': 144.950904, 'lux': 3.617},
#  {'lat': -37.820115, 'log': 144.950909, 'lux': 3.519},
#  {'lat': -37.820129, 'log': 144.950928, 'lux': 4.203},
#  {'lat': -37.820152, 'log': 144.95094, 'lux': 5.767},
#  {'lat': -37.819159, 'log': 144.950031, 'lux': 25.611},
#  {'lat': -37.81919, 'log': 144.950066, 'lux': 14.956},
#  {'lat': -37.819233, 'log': 144.950112, 'lux': 10.264},
#  {'lat': -37.819301, 'log': 144.950186, 'lux': 6.256},
#  {'lat': -37.81932, 'log': 144.950203, 'lux': 3.812},
#  {'lat': -37.819346, 'log': 144.950222, 'lux': 2.053},
#  {'lat': -37.819362, 'log': 144.950233, 'lux': 1.76},
#  {'lat': -37.819367, 'log': 144.950237, 'lux': 1.857},
#  {'lat': -37.820178, 'log': 144.950956, 'lux': 9.189},
#  {'lat': -37.820261, 'log': 144.951012, 'lux': 16.129},
#  {'lat': -37.820299, 'log': 144.951024, 'lux': 7.429},
#  {'lat': -37.820312, 'log': 144.951032, 'lux': 6.354},
#  {'lat': -37.82033, 'log': 144.951042, 'lux': 3.03},
#  {'lat': -37.820358, 'log': 144.951075, 'lux': 2.835},
#  {'lat': -37.820362, 'log': 144.951082, 'lux': 2.933},
#  {'lat': -37.820427, 'log': 144.95115, 'lux': 2.542},
#  {'lat': -37.820457, 'log': 144.951181, 'lux': 4.594},
#  {'lat': -37.821136, 'log': 144.951764, 'lux': 2.053},
#  {'lat': -37.818808, 'log': 144.949524, 'lux': 3.128},
#  {'lat': -37.81881, 'log': 144.949535, 'lux': 2.737},
#  {'lat': -37.818824, 'log': 144.949577, 'lux': 0.684},
#  {'lat': -37.818826, 'log': 144.949579, 'lux': 0.684},
#  {'lat': -37.818832, 'log': 144.949594, 'lux': 0.587},
#  {'lat': -37.818937, 'log': 144.949745, 'lux': 7.331},
#  {'lat': -37.819447, 'log': 144.95031, 'lux': 1.662},
#  {'lat': -37.819508, 'log': 144.950366, 'lux': 1.466},
#  {'lat': -37.819534, 'log': 144.95039, 'lux': 1.369},
#  {'lat': -37.819543, 'log': 144.950396, 'lux': 1.466},
#  {'lat': -37.819633, 'log': 144.95047, 'lux': 3.03},
#  {'lat': -37.819653, 'log': 144.950489, 'lux': 4.301},
#  {'lat': -37.819675, 'log': 144.950512, 'lux': 7.038},
#  {'lat': -37.81896, 'log': 144.949776, 'lux': 4.399},
#  {'lat': -37.818974, 'log': 144.949795, 'lux': 3.128},
#  {'lat': -37.818981, 'log': 144.949806, 'lux': 2.542},
#  {'lat': -37.818984, 'log': 144.94981, 'lux': 2.346},
#  {'lat': -37.819012, 'log': 144.949848, 'lux': 1.271},
#  {'lat': -37.81905, 'log': 144.949903, 'lux': 2.542},
#  {'lat': -37.819066, 'log': 144.949931, 'lux': 7.234},
#  {'lat': -37.819072, 'log': 144.949938, 'lux': 9.091},
#  {'lat': -37.819075, 'log': 144.949941, 'lux': 9.286},
#  {'lat': -37.819679, 'log': 144.950516, 'lux': 7.918},
#  {'lat': -37.819749, 'log': 144.950566, 'lux': 8.993},
#  {'lat': -37.819847, 'log': 144.950638, 'lux': 1.564},
#  {'lat': -37.819857, 'log': 144.950645, 'lux': 1.369},
#  {'lat': -37.819902, 'log': 144.950679, 'lux': 3.226},
#  {'lat': -37.821152, 'log': 144.951782, 'lux': 2.346},
#  {'lat': -37.821163, 'log': 144.951794, 'lux': 3.128},
#  {'lat': -37.821171, 'log': 144.951802, 'lux': 3.91},
#  {'lat': -37.821186, 'log': 144.951813, 'lux': 5.963},
#  {'lat': -37.821192, 'log': 144.951813, 'lux': 6.452},
#  {'lat': -37.821195, 'log': 144.951813, 'lux': 6.647},
#  {'lat': -37.821213, 'log': 144.951828, 'lux': 7.722},
#  {'lat': -37.819191, 'log': 144.96507, 'lux': 30.694},
#  {'lat': -37.819191, 'log': 144.96506, 'lux': 29.423},
#  {'lat': -37.819248, 'log': 144.964444, 'lux': 20.332},
#  {'lat': -37.819248, 'log': 144.964442, 'lux': 20.919},
#  {'lat': -37.819248, 'log': 144.964437, 'lux': 21.505},
#  {'lat': -37.819248, 'log': 144.964419, 'lux': 25.415},
#  {'lat': -37.819251, 'log': 144.964386, 'lux': 20.528},
#  {'lat': -37.819251, 'log': 144.964382, 'lux': 19.746},
#  {'lat': -37.819252, 'log': 144.96435, 'lux': 19.648},
#  {'lat': -37.819253, 'log': 144.964315, 'lux': 25.513},
#  {'lat': -37.819255, 'log': 144.964302, 'lux': 23.069},
#  {'lat': -37.819256, 'log': 144.964297, 'lux': 20.528},
#  {'lat': -37.819257, 'log': 144.964281, 'lux': 17.4},
#  {'lat': -37.820501, 'log': 144.951233, 'lux': 14.761},
#  {'lat': -37.820544, 'log': 144.951272, 'lux': 26.491},
#  {'lat': -37.820581, 'log': 144.951301, 'lux': 20.821},
#  {'lat': -37.820711, 'log': 144.951406, 'lux': 3.617},
#  {'lat': -37.820789, 'log': 144.95148, 'lux': 9.775},
#  {'lat': -37.820807, 'log': 144.951494, 'lux': 13.392},
#  {'lat': -37.820824, 'log': 144.951508, 'lux': 13.783},
#  {'lat': -37.820829, 'log': 144.951512, 'lux': 11.437},
#  {'lat': -37.820946, 'log': 144.951599, 'lux': 5.181},
#  {'lat': -37.821014, 'log': 144.951654, 'lux': 23.069},
#  {'lat': -37.821035, 'log': 144.951672, 'lux': 31.965},
#  {'lat': -37.821059, 'log': 144.951693, 'lux': 31.281},
#  {'lat': -37.821065, 'log': 144.951698, 'lux': 29.521},
#  {'lat': -37.82108, 'log': 144.951709, 'lux': 25.709},
#  {'lat': -37.821104, 'log': 144.95173, 'lux': 6.061},
#  {'lat': -37.819263, 'log': 144.96422, 'lux': 26.588},
#  {'lat': -37.819263, 'log': 144.964203, 'lux': 23.851},
#  {'lat': -37.819268, 'log': 144.964138, 'lux': 27.566},
#  {'lat': -37.819269, 'log': 144.964134, 'lux': 27.175},
#  {'lat': -37.81927, 'log': 144.964123, 'lux': 25.611},
#  {'lat': -37.819275, 'log': 144.964084, 'lux': 18.671},
#  {'lat': -37.819276, 'log': 144.964062, 'lux': 24.145},
#  {'lat': -37.819193, 'log': 144.965049, 'lux': 30.499},
#  {'lat': -37.819194, 'log': 144.965047, 'lux': 30.792},
#  {'lat': -37.819195, 'log': 144.965024, 'lux': 24.242},
#  {'lat': -37.819195, 'log': 144.964989, 'lux': 21.017},
#  {'lat': -37.819197, 'log': 144.964965, 'lux': 26.491},
#  {'lat': -37.819198, 'log': 144.964958, 'lux': 26.491},
#  {'lat': -37.8192, 'log': 144.964938, 'lux': 22.776},
#  {'lat': -37.819201, 'log': 144.964935, 'lux': 22.092},
#  {'lat': -37.81921, 'log': 144.964816, 'lux': 19.941},
#  {'lat': -37.819212, 'log': 144.964798, 'lux': 23.265},
#  {'lat': -37.819215, 'log': 144.96478, 'lux': 23.069},
#  {'lat': -37.819215, 'log': 144.964777, 'lux': 22.874},
#  {'lat': -37.819222, 'log': 144.964747, 'lux': 17.791},
#  {'lat': -37.819225, 'log': 144.964722, 'lux': 20.332},
#  {'lat': -37.819135, 'log': 144.950005, 'lux': 30.108},
#  {'lat': -37.819229, 'log': 144.964673, 'lux': 23.949},
#  {'lat': -37.819231, 'log': 144.964661, 'lux': 20.919},
#  {'lat': -37.819232, 'log': 144.964653, 'lux': 18.964},
#  {'lat': -37.819238, 'log': 144.964587, 'lux': 23.754},
#  {'lat': -37.81924, 'log': 144.964572, 'lux': 18.964},
#  {'lat': -37.819241, 'log': 144.964564, 'lux': 18.084},
#  {'lat': -37.819594, 'log': 144.963112, 'lux': 16.031},
#  {'lat': -37.819613, 'log': 144.963064, 'lux': 12.121},
#  {'lat': -37.819617, 'log': 144.963048, 'lux': 12.219},
#  {'lat': -37.819618, 'log': 144.963043, 'lux': 13.392},
#  {'lat': -37.819621, 'log': 144.96303, 'lux': 16.618},
#  {'lat': -37.819623, 'log': 144.963019, 'lux': 18.964},
#  {'lat': -37.819624, 'log': 144.963013, 'lux': 19.062},
#  {'lat': -37.819626, 'log': 144.962995, 'lux': 20.235},
#  {'lat': -37.81963, 'log': 144.962967, 'lux': 21.212},
#  {'lat': -37.819436, 'log': 144.963673, 'lux': 5.572},
#  {'lat': -37.819438, 'log': 144.963669, 'lux': 5.963},
#  {'lat': -37.819441, 'log': 144.963657, 'lux': 7.918},
#  {'lat': -37.819455, 'log': 144.963615, 'lux': 19.746},
#  {'lat': -37.819461, 'log': 144.963581, 'lux': 21.017},
#  {'lat': -37.819482, 'log': 144.963499, 'lux': 31.476},
#  {'lat': -37.819484, 'log': 144.963492, 'lux': 30.987},
#  {'lat': -37.819491, 'log': 144.963473, 'lux': 18.964},
#  {'lat': -37.819632, 'log': 144.962959, 'lux': 20.919},
#  {'lat': -37.819633, 'log': 144.962952, 'lux': 20.039},
#  {'lat': -37.819635, 'log': 144.962947, 'lux': 19.746},
#  {'lat': -37.81964, 'log': 144.962928, 'lux': 15.054},
#  {'lat': -37.819643, 'log': 144.962917, 'lux': 13.49},
#  {'lat': -37.819644, 'log': 144.962916, 'lux': 13.099},
#  {'lat': -37.819647, 'log': 144.962908, 'lux': 12.414},
#  {'lat': -37.819648, 'log': 144.962904, 'lux': 11.535},
#  {'lat': -37.819646, 'log': 144.962896, 'lux': 10.948},
#  {'lat': -37.819645, 'log': 144.962889, 'lux': 10.557},
#  {'lat': -37.819645, 'log': 144.962879, 'lux': 10.264},
#  {'lat': -37.819645, 'log': 144.962875, 'lux': 10.166},
#  {'lat': -37.819645, 'log': 144.962875, 'lux': 10.068},
#  {'lat': -37.819283, 'log': 144.96402, 'lux': 21.408},
#  {'lat': -37.819284, 'log': 144.964015, 'lux': 18.866},
#  {'lat': -37.819286, 'log': 144.964005, 'lux': 17.498},
#  {'lat': -37.81929, 'log': 144.963989, 'lux': 20.039},
#  {'lat': -37.819317, 'log': 144.963942, 'lux': 18.475},
#  {'lat': -37.819319, 'log': 144.96394, 'lux': 17.889},
#  {'lat': -37.819323, 'log': 144.963931, 'lux': 14.761},
#  {'lat': -37.819347, 'log': 144.96389, 'lux': 14.174},
#  {'lat': -37.819511, 'log': 144.963394, 'lux': 19.648},
#  {'lat': -37.81952, 'log': 144.963361, 'lux': 14.272},
#  {'lat': -37.819524, 'log': 144.963344, 'lux': 9.775},
#  {'lat': -37.819526, 'log': 144.963336, 'lux': 7.234},
#  {'lat': -37.819527, 'log': 144.963331, 'lux': 5.963},
#  {'lat': -37.819528, 'log': 144.963328, 'lux': 5.474},
#  {'lat': -37.819529, 'log': 144.963326, 'lux': 5.279},
#  {'lat': -37.81953, 'log': 144.963318, 'lux': 4.79},
#  {'lat': -37.819533, 'log': 144.963308, 'lux': 6.452},
#  {'lat': -37.819534, 'log': 144.963303, 'lux': 6.452},
#  {'lat': -37.819367, 'log': 144.963854, 'lux': 8.016},
#  {'lat': -37.819378, 'log': 144.963837, 'lux': 9.286},
#  {'lat': -37.819399, 'log': 144.963776, 'lux': 9.482},
#  {'lat': -37.819402, 'log': 144.963768, 'lux': 8.211},
#  {'lat': -37.819419, 'log': 144.963722, 'lux': 6.843},
#  {'lat': -37.819429, 'log': 144.963696, 'lux': 5.083},
#  {'lat': -37.819551, 'log': 144.963249, 'lux': 9.775},
#  {'lat': -37.819553, 'log': 144.963236, 'lux': 2.346},
#  {'lat': -37.819557, 'log': 144.963216, 'lux': 1.075},
#  {'lat': -37.819561, 'log': 144.963206, 'lux': 0.88},
#  {'lat': -37.819565, 'log': 144.963196, 'lux': 0.782},
#  {'lat': -37.819567, 'log': 144.963186, 'lux': 0.782},
#  {'lat': -37.819576, 'log': 144.963158, 'lux': 3.617},
#  {'lat': -37.819577, 'log': 144.963156, 'lux': 3.715},
#  {'lat': -37.819578, 'log': 144.963155, 'lux': 4.008},
#  {'lat': -37.819581, 'log': 144.963148, 'lux': 7.234},
#  {'lat': -37.81834, 'log': 144.974709, 'lux': 0.978},
#  {'lat': -37.818341, 'log': 144.974693, 'lux': 1.564},
#  {'lat': -37.818344, 'log': 144.974618, 'lux': 9.091},
#  {'lat': -37.818344, 'log': 144.974592, 'lux': 22.287},
#  {'lat': -37.818345, 'log': 144.974584, 'lux': 18.573},
#  {'lat': -37.818346, 'log': 144.974576, 'lux': 16.129},
#  {'lat': -37.818347, 'log': 144.974569, 'lux': 17.107},
#  {'lat': -37.818348, 'log': 144.974545, 'lux': 13.783},
#  {'lat': -37.818348, 'log': 144.974478, 'lux': 2.542},
#  {'lat': -37.818389, 'log': 144.973679, 'lux': 9.189},
#  {'lat': -37.81839, 'log': 144.973658, 'lux': 4.301},
#  {'lat': -37.81839, 'log': 144.973602, 'lux': 3.519},
#  {'lat': -37.81839, 'log': 144.973598, 'lux': 4.106},
#  {'lat': -37.818392, 'log': 144.973579, 'lux': 10.557},
#  {'lat': -37.818393, 'log': 144.973568, 'lux': 21.994},
#  {'lat': -37.818393, 'log': 144.973564, 'lux': 26.588},
#  {'lat': -37.818394, 'log': 144.973545, 'lux': 38.612},
#  {'lat': -37.818395, 'log': 144.973534, 'lux': 48.778},
#  {'lat': -37.818398, 'log': 144.973495, 'lux': 9.286},
#  {'lat': -37.818398, 'log': 144.973492, 'lux': 7.918},
#  {'lat': -37.818401, 'log': 144.97345, 'lux': 2.542},
#  {'lat': -37.818402, 'log': 144.97344, 'lux': 2.639},
#  {'lat': -37.819645, 'log': 144.962875, 'lux': 10.068},
#  {'lat': -37.819645, 'log': 144.962875, 'lux': 10.068},
#  {'lat': -37.819645, 'log': 144.962875, 'lux': 10.068},
#  {'lat': -37.818325, 'log': 144.975037, 'lux': 4.497},
#  {'lat': -37.818325, 'log': 144.975029, 'lux': 4.888},
#  {'lat': -37.818329, 'log': 144.974976, 'lux': 8.602},
#  {'lat': -37.818329, 'log': 144.974937, 'lux': 25.22},
#  {'lat': -37.818336, 'log': 144.974834, 'lux': 4.008},
#  {'lat': -37.818337, 'log': 144.974816, 'lux': 11.144},
#  {'lat': -37.81834, 'log': 144.974781, 'lux': 23.265},
#  {'lat': -37.818504, 'log': 144.97121, 'lux': 4.594},
#  {'lat': -37.818404, 'log': 144.973409, 'lux': 3.128},
#  {'lat': -37.818404, 'log': 144.973404, 'lux': 3.226},
#  {'lat': -37.818413, 'log': 144.973282, 'lux': 4.106},
#  {'lat': -37.818413, 'log': 144.973276, 'lux': 3.91},
#  {'lat': -37.818413, 'log': 144.973271, 'lux': 4.203},
#  {'lat': -37.818414, 'log': 144.97326, 'lux': 4.203},
#  {'lat': -37.818417, 'log': 144.973217, 'lux': 2.444},
#  {'lat': -37.818417, 'log': 144.973209, 'lux': 2.542},
#  {'lat': -37.818417, 'log': 144.973194, 'lux': 3.617},
#  {'lat': -37.818352, 'log': 144.974403, 'lux': 9.971},
#  {'lat': -37.818352, 'log': 144.974396, 'lux': 15.347},
#  {'lat': -37.818352, 'log': 144.974393, 'lux': 23.46},
#  {'lat': -37.818353, 'log': 144.974365, 'lux': 42.033},
#  {'lat': -37.818359, 'log': 144.974251, 'lux': 2.346},
#  {'lat': -37.818359, 'log': 144.974243, 'lux': 3.519},
#  {'lat': -37.818361, 'log': 144.97423, 'lux': 6.549},
#  {'lat': -37.818363, 'log': 144.974197, 'lux': 36.95},
#  {'lat': -37.818363, 'log': 144.974163, 'lux': 34.018},
#  {'lat': -37.818363, 'log': 144.974152, 'lux': 33.236},
#  {'lat': -37.818363, 'log': 144.974148, 'lux': 32.845},
#  {'lat': -37.818364, 'log': 144.974117, 'lux': 20.137},
#  {'lat': -37.818367, 'log': 144.974072, 'lux': 1.173},
#  {'lat': -37.818367, 'log': 144.974061, 'lux': 1.564},
#  {'lat': -37.818367, 'log': 144.974058, 'lux': 1.564},
#  {'lat': -37.819435, 'log': 144.963676, 'lux': 5.474},
#  {'lat': -37.818368, 'log': 144.973936, 'lux': 15.054},
#  {'lat': -37.818372, 'log': 144.973919, 'lux': 14.467},
#  {'lat': -37.818375, 'log': 144.973902, 'lux': 8.016},
#  {'lat': -37.818382, 'log': 144.973808, 'lux': 13.587},
#  {'lat': -37.818383, 'log': 144.973797, 'lux': 18.475},
#  {'lat': -37.818384, 'log': 144.973782, 'lux': 28.739},
#  {'lat': -37.818384, 'log': 144.973778, 'lux': 32.649},
#  {'lat': -37.818384, 'log': 144.973774, 'lux': 41.74},
#  {'lat': -37.818386, 'log': 144.973751, 'lux': 31.378},
#  {'lat': -37.818386, 'log': 144.97373, 'lux': 29.717},
#  {'lat': -37.818481, 'log': 144.971655, 'lux': 20.039},
#  {'lat': -37.818483, 'log': 144.971632, 'lux': 7.918},
#  {'lat': -37.818485, 'log': 144.97161, 'lux': 5.572},
#  {'lat': -37.818488, 'log': 144.971565, 'lux': 4.497},
#  {'lat': -37.818489, 'log': 144.971561, 'lux': 5.083},
#  {'lat': -37.818489, 'log': 144.971551, 'lux': 5.963},
#  {'lat': -37.81849, 'log': 144.971516, 'lux': 19.648},
#  {'lat': -37.818494, 'log': 144.97147, 'lux': 8.504},
#  {'lat': -37.818496, 'log': 144.971443, 'lux': 3.617},
#  {'lat': -37.818496, 'log': 144.971439, 'lux': 3.03},
#  {'lat': -37.818447, 'log': 144.97237, 'lux': 4.497},
#  {'lat': -37.818451, 'log': 144.972298, 'lux': 23.754},
#  {'lat': -37.818451, 'log': 144.972284, 'lux': 19.062},
#  {'lat': -37.818451, 'log': 144.97226, 'lux': 6.061},
#  {'lat': -37.818453, 'log': 144.972229, 'lux': 1.857},
#  {'lat': -37.818454, 'log': 144.972225, 'lux': 1.76},
#  {'lat': -37.818455, 'log': 144.972209, 'lux': 1.76},
#  {'lat': -37.818497, 'log': 144.971413, 'lux': 1.76},
#  {'lat': -37.818497, 'log': 144.971373, 'lux': 4.203},
#  {'lat': -37.818497, 'log': 144.971356, 'lux': 8.602},
#  {'lat': -37.8185, 'log': 144.971324, 'lux': 27.077},
#  {'lat': -37.818501, 'log': 144.971293, 'lux': 33.92},
#  {'lat': -37.818503, 'log': 144.97126, 'lux': 24.438},
#  {'lat': -37.818504, 'log': 144.971237, 'lux': 7.918},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818425, 'log': 144.973058, 'lux': 1.76},
#  {'lat': -37.818427, 'log': 144.973022, 'lux': 1.76},
#  {'lat': -37.818428, 'log': 144.972951, 'lux': 11.144},
#  {'lat': -37.818431, 'log': 144.9729, 'lux': 16.227},
#  {'lat': -37.818432, 'log': 144.972878, 'lux': 3.715},
#  {'lat': -37.818432, 'log': 144.972874, 'lux': 3.421},
#  {'lat': -37.818432, 'log': 144.972866, 'lux': 2.151},
#  {'lat': -37.818455, 'log': 144.972163, 'lux': 5.083},
#  {'lat': -37.818461, 'log': 144.97202, 'lux': 2.248},
#  {'lat': -37.818466, 'log': 144.971962, 'lux': 4.594},
#  {'lat': -37.818466, 'log': 144.971954, 'lux': 6.452},
#  {'lat': -37.818466, 'log': 144.971949, 'lux': 9.971},
#  {'lat': -37.818466, 'log': 144.971914, 'lux': 21.994},
#  {'lat': -37.818437, 'log': 144.972758, 'lux': 0.782},
#  {'lat': -37.818439, 'log': 144.972733, 'lux': 1.173},
#  {'lat': -37.818439, 'log': 144.972713, 'lux': 1.075},
#  {'lat': -37.818439, 'log': 144.972691, 'lux': 0.684},
#  {'lat': -37.818439, 'log': 144.972687, 'lux': 0.587},
#  {'lat': -37.81844, 'log': 144.972656, 'lux': 0.293},
#  {'lat': -37.818442, 'log': 144.972631, 'lux': 0.489},
#  {'lat': -37.818443, 'log': 144.972607, 'lux': 3.128},
#  {'lat': -37.818442, 'log': 144.9726, 'lux': 2.346},
#  {'lat': -37.818441, 'log': 144.972579, 'lux': 7.625},
#  {'lat': -37.818443, 'log': 144.972481, 'lux': 10.753},
#  {'lat': -37.818443, 'log': 144.972477, 'lux': 10.655},
#  {'lat': -37.818469, 'log': 144.971873, 'lux': 17.595},
#  {'lat': -37.818471, 'log': 144.971809, 'lux': 2.835},
#  {'lat': -37.818471, 'log': 144.971802, 'lux': 2.933},
#  {'lat': -37.818474, 'log': 144.971771, 'lux': 6.256},
#  {'lat': -37.818474, 'log': 144.971764, 'lux': 8.7},
#  {'lat': -37.818476, 'log': 144.971701, 'lux': 13.881},
#  {'lat': -37.81848, 'log': 144.971663, 'lux': 23.851},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.684},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818549, 'log': 144.971685, 'lux': 3.812},
#  {'lat': -37.818546, 'log': 144.97171, 'lux': 3.519},
#  {'lat': -37.818545, 'log': 144.971723, 'lux': 3.421},
#  {'lat': -37.818544, 'log': 144.971731, 'lux': 3.421},
#  {'lat': -37.818548, 'log': 144.971831, 'lux': 4.203},
#  {'lat': -37.818549, 'log': 144.971837, 'lux': 4.399},
#  {'lat': -37.818504, 'log': 144.971196, 'lux': 4.79},
#  {'lat': -37.818504, 'log': 144.971186, 'lux': 5.767},
#  {'lat': -37.818504, 'log': 144.971135, 'lux': 47.312},
#  {'lat': -37.818504, 'log': 144.971127, 'lux': 39.687},
#  {'lat': -37.818504, 'log': 144.9711, 'lux': 17.595},
#  {'lat': -37.818504, 'log': 144.971092, 'lux': 13.881},
#  {'lat': -37.818504, 'log': 144.971068, 'lux': 11.144},
#  {'lat': -37.818502, 'log': 144.971034, 'lux': 4.497},
#  {'lat': -37.818501, 'log': 144.971026, 'lux': 2.933},
#  {'lat': -37.8185, 'log': 144.971018, 'lux': 2.151},
#  {'lat': -37.818497, 'log': 144.970998, 'lux': 1.369},
#  {'lat': -37.818497, 'log': 144.970985, 'lux': 1.075},
#  {'lat': -37.818497, 'log': 144.970968, 'lux': 0.782},
#  {'lat': -37.818497, 'log': 144.970951, 'lux': 0.684},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818566, 'log': 144.971912, 'lux': 4.888},
#  {'lat': -37.818567, 'log': 144.971916, 'lux': 4.888},
#  {'lat': -37.818582, 'log': 144.971956, 'lux': 2.835},
#  {'lat': -37.818591, 'log': 144.971968, 'lux': 3.128},
#  {'lat': -37.818599, 'log': 144.971987, 'lux': 4.106},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.684},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.684},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.684},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.684},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.684},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.684},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.818497, 'log': 144.970947, 'lux': 0.587},
#  {'lat': -37.81855, 'log': 144.971559, 'lux': 5.279},
#  {'lat': -37.81855, 'log': 144.97157, 'lux': 7.038},
#  {'lat': -37.81855, 'log': 144.971591, 'lux': 9.482},
#  {'lat': -37.81855, 'log': 144.97162, 'lux': 12.414},
#  {'lat': -37.818871, 'log': 144.973165, 'lux': 11.437},
#  {'lat': -37.818886, 'log': 144.973206, 'lux': 8.016},
#  {'lat': -37.818927, 'log': 144.973289, 'lux': 4.399},
#  {'lat': -37.818954, 'log': 144.97332, 'lux': 8.309},
#  {'lat': -37.818966, 'log': 144.97333, 'lux': 14.663},
#  {'lat': -37.818683, 'log': 144.97253, 'lux': 8.211},
#  {'lat': -37.818689, 'log': 144.972555, 'lux': 4.106},
#  {'lat': -37.818695, 'log': 144.97258, 'lux': 4.497},
#  {'lat': -37.818715, 'log': 144.972664, 'lux': 5.376},
#  {'lat': -37.818725, 'log': 144.97271, 'lux': 10.948},
#  {'lat': -37.81873, 'log': 144.972724, 'lux': 14.076},
#  {'lat': -37.81897, 'log': 144.973333, 'lux': 15.054},
#  {'lat': -37.818974, 'log': 144.973335, 'lux': 15.836},
#  {'lat': -37.818985, 'log': 144.973343, 'lux': 18.671},
#  {'lat': -37.819034, 'log': 144.973425, 'lux': 12.219},
#  {'lat': -37.819057, 'log': 144.973465, 'lux': 24.145},
#  {'lat': -37.819062, 'log': 144.973476, 'lux': 28.935},
#  {'lat': -37.819075, 'log': 144.973507, 'lux': 36.266},
#  {'lat': -37.818607, 'log': 144.972028, 'lux': 9.58},
#  {'lat': -37.818608, 'log': 144.972033, 'lux': 11.144},
#  {'lat': -37.818619, 'log': 144.972112, 'lux': 13.783},
#  {'lat': -37.818619, 'log': 144.972137, 'lux': 6.94},
#  {'lat': -37.818625, 'log': 144.972173, 'lux': 1.173},
#  {'lat': -37.818632, 'log': 144.972206, 'lux': 3.421},
#  {'lat': -37.818637, 'log': 144.972233, 'lux': 4.692},
#  {'lat': -37.818638, 'log': 144.972237, 'lux': 4.888},
#  {'lat': -37.818752, 'log': 144.972806, 'lux': 4.985},
#  {'lat': -37.818759, 'log': 144.972834, 'lux': 3.03},
#  {'lat': -37.818759, 'log': 144.972837, 'lux': 2.835},
#  {'lat': -37.818789, 'log': 144.972939, 'lux': 0.391},
#  {'lat': -37.818792, 'log': 144.972946, 'lux': 0.391},
#  {'lat': -37.818645, 'log': 144.972283, 'lux': 6.94},
#  {'lat': -37.818645, 'log': 144.97229, 'lux': 9.482},
#  {'lat': -37.818646, 'log': 144.972301, 'lux': 10.948},
#  {'lat': -37.818649, 'log': 144.972328, 'lux': 7.82},
#  {'lat': -37.818653, 'log': 144.972351, 'lux': 4.594},
#  {'lat': -37.818665, 'log': 144.972412, 'lux': 0.782},
#  {'lat': -37.818679, 'log': 144.972485, 'lux': 9.971},
#  {'lat': -37.81882, 'log': 144.973026, 'lux': 0.391},
#  {'lat': -37.818833, 'log': 144.973059, 'lux': 1.955},
#  {'lat': -37.818841, 'log': 144.973081, 'lux': 2.542},
#  {'lat': -37.818847, 'log': 144.973096, 'lux': 3.91},
#  {'lat': -37.818849, 'log': 144.973103, 'lux': 4.301},
#  {'lat': -37.818859, 'log': 144.973133, 'lux': 6.354},
#  {'lat': -37.818865, 'log': 144.97315, 'lux': 10.264},
#  {'lat': -37.81928, 'log': 144.973928, 'lux': 26.197},
#  {'lat': -37.819293, 'log': 144.973951, 'lux': 32.747},
#  {'lat': -37.819297, 'log': 144.973958, 'lux': 29.032},
#  {'lat': -37.819303, 'log': 144.973971, 'lux': 28.152},
#  {'lat': -37.819305, 'log': 144.973976, 'lux': 25.806},
#  {'lat': -37.819308, 'log': 144.973981, 'lux': 22.581},
#  {'lat': -37.819329, 'log': 144.974018, 'lux': 0.391},
#  {'lat': -37.81933, 'log': 144.97402, 'lux': 0.293},
#  {'lat': -37.819336, 'log': 144.97403, 'lux': 0.293},
#  {'lat': -37.819339, 'log': 144.974035, 'lux': 0.293},
#  {'lat': -37.819355, 'log': 144.97406, 'lux': 0.098},
#  {'lat': -37.81936, 'log': 144.974068, 'lux': 0.098},
#  {'lat': -37.819365, 'log': 144.974075, 'lux': 0.196},
#  {'lat': -37.819366, 'log': 144.974078, 'lux': 0.293},
#  {'lat': -37.819764, 'log': 144.974655, 'lux': 5.767},
#  {'lat': -37.819767, 'log': 144.974659, 'lux': 4.985},
#  {'lat': -37.819771, 'log': 144.974667, 'lux': 6.745},
#  {'lat': -37.81978, 'log': 144.974682, 'lux': 8.7},
#  {'lat': -37.81979, 'log': 144.97469, 'lux': 9.677},
#  {'lat': -37.819796, 'log': 144.974693, 'lux': 9.677},
#  {'lat': -37.81982, 'log': 144.97472, 'lux': 19.746},
#  {'lat': -37.819845, 'log': 144.974757, 'lux': 20.528},
#  {'lat': -37.81987, 'log': 144.974787, 'lux': 9.384},
#  {'lat': -37.819872, 'log': 144.97479, 'lux': 8.798},
#  {'lat': -37.81988, 'log': 144.9748, 'lux': 5.279},
#  {'lat': -37.819883, 'log': 144.974805, 'lux': 2.444},
#  {'lat': -37.819902, 'log': 144.974827, 'lux': 0.098},
#  {'lat': -37.81908, 'log': 144.973518, 'lux': 34.8},
#  {'lat': -37.81911, 'log': 144.973577, 'lux': 13.392},
#  {'lat': -37.819112, 'log': 144.973579, 'lux': 13.099},
#  {'lat': -37.819113, 'log': 144.973582, 'lux': 11.926},
#  {'lat': -37.81912, 'log': 144.973592, 'lux': 8.113},
#  {'lat': -37.819129, 'log': 144.973607, 'lux': 3.226},
#  {'lat': -37.819132, 'log': 144.973612, 'lux': 3.03},
#  {'lat': -37.819145, 'log': 144.973633, 'lux': 1.173},
#  {'lat': -37.81915, 'log': 144.973643, 'lux': 0.293},
#  {'lat': -37.819164, 'log': 144.973679, 'lux': 0.293},
#  {'lat': -37.819212, 'log': 144.97377, 'lux': 0.293},
#  {'lat': -37.819214, 'log': 144.973773, 'lux': 0.293},
#  {'lat': -37.819233, 'log': 144.97382, 'lux': 1.466},
#  {'lat': -37.819257, 'log': 144.973866, 'lux': 8.407},
#  {'lat': -37.819262, 'log': 144.973885, 'lux': 6.354},
#  {'lat': -37.819945, 'log': 144.974876, 'lux': 0.196},
#  {'lat': -37.81995, 'log': 144.974881, 'lux': 0.293},
#  {'lat': -37.819979, 'log': 144.974917, 'lux': 1.857},
#  {'lat': -37.819998, 'log': 144.97494, 'lux': 2.737},
#  {'lat': -37.820016, 'log': 144.974958, 'lux': 5.474},
#  {'lat': -37.819379, 'log': 144.974098, 'lux': 0.587},
#  {'lat': -37.819395, 'log': 144.974124, 'lux': 1.075},
#  {'lat': -37.819401, 'log': 144.974134, 'lux': 0.391},
#  {'lat': -37.819403, 'log': 144.974136, 'lux': 0.88},
#  {'lat': -37.819406, 'log': 144.974141, 'lux': 1.075},
#  {'lat': -37.819439, 'log': 144.97419, 'lux': 3.421},
#  {'lat': -37.819445, 'log': 144.974202, 'lux': 3.617},
#  {'lat': -37.819455, 'log': 144.97422, 'lux': 6.843},
#  {'lat': -37.819473, 'log': 144.974251, 'lux': 6.843},
#  {'lat': -37.819481, 'log': 144.974264, 'lux': 8.7},
#  {'lat': -37.819483, 'log': 144.974266, 'lux': 8.504},
#  {'lat': -37.819506, 'log': 144.974298, 'lux': 7.429},
#  {'lat': -37.819524, 'log': 144.97433, 'lux': 8.309},
#  {'lat': -37.819535, 'log': 144.974351, 'lux': 8.113},
#  {'lat': -37.819551, 'log': 144.974378, 'lux': 15.249},
#  {'lat': -37.819561, 'log': 144.974391, 'lux': 18.671},
#  {'lat': -37.819569, 'log': 144.974401, 'lux': 20.919},
#  {'lat': -37.818682, 'log': 144.972513, 'lux': 9.58},
#  {'lat': -37.819631, 'log': 144.974493, 'lux': 23.754},
#  {'lat': -37.819644, 'log': 144.974508, 'lux': 17.107},
#  {'lat': -37.819648, 'log': 144.974511, 'lux': 11.535},
#  {'lat': -37.819652, 'log': 144.974514, 'lux': 8.407},
#  {'lat': -37.819656, 'log': 144.974518, 'lux': 10.753},
#  {'lat': -37.819679, 'log': 144.974548, 'lux': 2.053},
#  {'lat': -37.819696, 'log': 144.974571, 'lux': 0.587},
#  {'lat': -37.819698, 'log': 144.974573, 'lux': 1.564},
#  {'lat': -37.819702, 'log': 144.974579, 'lux': 2.933},
#  {'lat': -37.819731, 'log': 144.974612, 'lux': 4.985},
#  {'lat': -37.820785, 'log': 144.97568, 'lux': 0.587},
#  {'lat': -37.820786, 'log': 144.975681, 'lux': 0.684},
#  {'lat': -37.82079, 'log': 144.975684, 'lux': 0.88},
#  {'lat': -37.820791, 'log': 144.975685, 'lux': 0.978},
#  {'lat': -37.820831, 'log': 144.975717, 'lux': 12.708},
#  {'lat': -37.820839, 'log': 144.975723, 'lux': 11.926},
#  {'lat': -37.820375, 'log': 144.975339, 'lux': 13.587},
#  {'lat': -37.820396, 'log': 144.975357, 'lux': 11.144},
#  {'lat': -37.820398, 'log': 144.975358, 'lux': 10.459},
#  {'lat': -37.820407, 'log': 144.975368, 'lux': 5.181},
#  {'lat': -37.820436, 'log': 144.975392, 'lux': 0.587},
#  {'lat': -37.820919, 'log': 144.97579, 'lux': 0.88},
#  {'lat': -37.820941, 'log': 144.975808, 'lux': 3.03},
#  {'lat': -37.820959, 'log': 144.975828, 'lux': 10.264},
#  {'lat': -37.820979, 'log': 144.975849, 'lux': 37.048},
#  {'lat': -37.820981, 'log': 144.97585, 'lux': 36.852},
#  {'lat': -37.821002, 'log': 144.975864, 'lux': 21.994},
#  {'lat': -37.821007, 'log': 144.97587, 'lux': 20.235},
#  {'lat': -37.821018, 'log': 144.975882, 'lux': 17.204},
#  {'lat': -37.82129, 'log': 144.976102, 'lux': 37.439},
#  {'lat': -37.820063, 'log': 144.975004, 'lux': 4.301},
#  {'lat': -37.820077, 'log': 144.97502, 'lux': 1.369},
#  {'lat': -37.82014, 'log': 144.975089, 'lux': 0.489},
#  {'lat': -37.820158, 'log': 144.975109, 'lux': 0.196},
#  {'lat': -37.820161, 'log': 144.975112, 'lux': 0.293},
#  {'lat': -37.820184, 'log': 144.975136, 'lux': 0.0},
#  {'lat': -37.820474, 'log': 144.975428, 'lux': 1.564},
#  {'lat': -37.820478, 'log': 144.975433, 'lux': 1.857},
#  {'lat': -37.820524, 'log': 144.975471, 'lux': 34.995},
#  {'lat': -37.820543, 'log': 144.975496, 'lux': 99.218},
#  {'lat': -37.820549, 'log': 144.975501, 'lux': 99.218},
#  {'lat': -37.820554, 'log': 144.975505, 'lux': 99.12},
#  {'lat': -37.820573, 'log': 144.975517, 'lux': 12.414},
#  {'lat': -37.820575, 'log': 144.975518, 'lux': 9.482},
#  {'lat': -37.820612, 'log': 144.97555, 'lux': 0.587},
#  {'lat': -37.820238, 'log': 144.975176, 'lux': 0.196},
#  {'lat': -37.82025, 'log': 144.975192, 'lux': 0.098},
#  {'lat': -37.820261, 'log': 144.975207, 'lux': 0.196},
#  {'lat': -37.820263, 'log': 144.975209, 'lux': 0.196},
#  {'lat': -37.820267, 'log': 144.975214, 'lux': 0.196},
#  {'lat': -37.820328, 'log': 144.975286, 'lux': 0.782},
#  {'lat': -37.820337, 'log': 144.975297, 'lux': 1.662},
#  {'lat': -37.820341, 'log': 144.9753, 'lux': 2.151},
#  {'lat': -37.820694, 'log': 144.975606, 'lux': 34.115},
#  {'lat': -37.820705, 'log': 144.975614, 'lux': 50.733},
#  {'lat': -37.820709, 'log': 144.975616, 'lux': 54.252},
#  {'lat': -37.820712, 'log': 144.975622, 'lux': 47.996},
#  {'lat': -37.820727, 'log': 144.975644, 'lux': 17.107},
#  {'lat': -37.820728, 'log': 144.975647, 'lux': 14.174},
#  {'lat': -37.820762, 'log': 144.975674, 'lux': 0.196},
#  {'lat': -37.821301, 'log': 144.97611, 'lux': 42.522},
#  {'lat': -37.821308, 'log': 144.976115, 'lux': 39.101},
#  {'lat': -37.821313, 'log': 144.976118, 'lux': 30.108},
#  {'lat': -37.821337, 'log': 144.976131, 'lux': 4.594},
#  {'lat': -37.821346, 'log': 144.976135, 'lux': 2.639},
#  {'lat': -37.821351, 'log': 144.97614, 'lux': 2.542},
#  {'lat': -37.821356, 'log': 144.976145, 'lux': 2.053},
#  {'lat': -37.821374, 'log': 144.976163, 'lux': 6.256},
#  {'lat': -37.821405, 'log': 144.976191, 'lux': 8.016},
#  {'lat': -37.821408, 'log': 144.976194, 'lux': 4.008},
#  {'lat': -37.821421, 'log': 144.976201, 'lux': 16.618},
#  {'lat': -37.821431, 'log': 144.976206, 'lux': 5.474},
#  {'lat': -37.821447, 'log': 144.976219, 'lux': 2.151},
#  {'lat': -37.821457, 'log': 144.976232, 'lux': 4.106},
#  {'lat': -37.819838, 'log': 144.97585, 'lux': 16.618},
#  {'lat': -37.819835, 'log': 144.975844, 'lux': 19.159},
#  {'lat': -37.819834, 'log': 144.975843, 'lux': 22.874},
#  {'lat': -37.819816, 'log': 144.975798, 'lux': 1.173},
#  {'lat': -37.819805, 'log': 144.975769, 'lux': 3.715},
#  {'lat': -37.819805, 'log': 144.975766, 'lux': 4.399},
#  {'lat': -37.819801, 'log': 144.975753, 'lux': 4.888},
#  {'lat': -37.819794, 'log': 144.97574, 'lux': 12.61},
#  {'lat': -37.819794, 'log': 144.975739, 'lux': 14.956},
#  {'lat': -37.821125, 'log': 144.97596, 'lux': 1.271},
#  {'lat': -37.82114, 'log': 144.975967, 'lux': 1.564},
#  {'lat': -37.821144, 'log': 144.975972, 'lux': 1.662},
#  {'lat': -37.821164, 'log': 144.975999, 'lux': 1.662},
#  {'lat': -37.821167, 'log': 144.976002, 'lux': 1.173},
#  {'lat': -37.821185, 'log': 144.976013, 'lux': 1.564},
#  {'lat': -37.821187, 'log': 144.976013, 'lux': 1.564},
#  {'lat': -37.821197, 'log': 144.97602, 'lux': 1.564},
#  {'lat': -37.821212, 'log': 144.976035, 'lux': 1.662},
#  {'lat': -37.821215, 'log': 144.976038, 'lux': 1.662},
#  {'lat': -37.82122, 'log': 144.976044, 'lux': 1.857},
#  {'lat': -37.821231, 'log': 144.976051, 'lux': 1.662},
#  {'lat': -37.821237, 'log': 144.976055, 'lux': 0.978},
#  {'lat': -37.821247, 'log': 144.976061, 'lux': 1.173},
#  {'lat': -37.821269, 'log': 144.976077, 'lux': 9.971},
#  {'lat': -37.821277, 'log': 144.976086, 'lux': 19.55},
#  {'lat': -37.821282, 'log': 144.976093, 'lux': 26.588},
#  {'lat': -37.81932, 'log': 144.974403, 'lux': 3.812},
#  {'lat': -37.819788, 'log': 144.975718, 'lux': 25.513},
#  {'lat': -37.819784, 'log': 144.975701, 'lux': 21.505},
#  {'lat': -37.819775, 'log': 144.975672, 'lux': 9.58},
#  {'lat': -37.819766, 'log': 144.975647, 'lux': 2.248},
#  {'lat': -37.819743, 'log': 144.975584, 'lux': 4.985},
#  {'lat': -37.819741, 'log': 144.975579, 'lux': 5.279},
#  {'lat': -37.81973, 'log': 144.975548, 'lux': 5.572},
#  {'lat': -37.821463, 'log': 144.97624, 'lux': 11.632},
#  {'lat': -37.82149, 'log': 144.97626, 'lux': 45.846},
#  {'lat': -37.821495, 'log': 144.976266, 'lux': 48.387},
#  {'lat': -37.821498, 'log': 144.97627, 'lux': 48.485},
#  {'lat': -37.82152, 'log': 144.976291, 'lux': 10.557},
#  {'lat': -37.821524, 'log': 144.976294, 'lux': 7.527},
#  {'lat': -37.821529, 'log': 144.976296, 'lux': 7.038},
#  {'lat': -37.821541, 'log': 144.976303, 'lux': 3.421},
#  {'lat': -37.821547, 'log': 144.976311, 'lux': 3.715},
#  {'lat': -37.821548, 'log': 144.976313, 'lux': 3.519},
#  {'lat': -37.821556, 'log': 144.976323, 'lux': 3.128},
#  {'lat': -37.821596, 'log': 144.976352, 'lux': 10.753},
#  {'lat': -37.821604, 'log': 144.976357, 'lux': 6.843},
#  {'lat': -37.821642, 'log': 144.976389, 'lux': 0.978},
#  {'lat': -37.821692, 'log': 144.976435, 'lux': 1.271},
#  {'lat': -37.821705, 'log': 144.976443, 'lux': 1.76},
#  {'lat': -37.821719, 'log': 144.976452, 'lux': 7.527},
#  {'lat': -37.821733, 'log': 144.976471, 'lux': 9.189},
#  {'lat': -37.821737, 'log': 144.976476, 'lux': 11.144},
#  {'lat': -37.82174, 'log': 144.976481, 'lux': 9.677},
#  {'lat': -37.821759, 'log': 144.976499, 'lux': 22.287},
#  {'lat': -37.821771, 'log': 144.976501, 'lux': 31.281},
#  {'lat': -37.82178, 'log': 144.976507, 'lux': 33.138},
#  {'lat': -37.821783, 'log': 144.976513, 'lux': 32.063},
#  {'lat': -37.821784, 'log': 144.976516, 'lux': 30.694},
#  {'lat': -37.821785, 'log': 144.976517, 'lux': 31.085},
#  {'lat': -37.821785, 'log': 144.976517, 'lux': 29.619},
#  {'lat': -37.821785, 'log': 144.976517, 'lux': 29.521},
#  {'lat': -37.821785, 'log': 144.976517, 'lux': 29.326},
#  {'lat': -37.821785, 'log': 144.976517, 'lux': 29.326},
#  {'lat': -37.821785, 'log': 144.976517, 'lux': 29.326},
#  {'lat': -37.821785, 'log': 144.976517, 'lux': 29.423},
#  {'lat': -37.819842, 'log': 144.975859, 'lux': 13.196},
#  {'lat': -37.819842, 'log': 144.975857, 'lux': 11.535},
#  {'lat': -37.819381, 'log': 144.974622, 'lux': 52.981},
#  {'lat': -37.819379, 'log': 144.974616, 'lux': 45.161},
#  {'lat': -37.819374, 'log': 144.974609, 'lux': 23.656},
#  {'lat': -37.819371, 'log': 144.974609, 'lux': 17.302},
#  {'lat': -37.819366, 'log': 144.974594, 'lux': 3.421},
#  {'lat': -37.819366, 'log': 144.974584, 'lux': 3.617},
#  {'lat': -37.819557, 'log': 144.97506, 'lux': 10.655},
#  {'lat': -37.819546, 'log': 144.97503, 'lux': 17.595},
#  {'lat': -37.819532, 'log': 144.974998, 'lux': 8.504},
#  {'lat': -37.819529, 'log': 144.974983, 'lux': 11.828},
#  {'lat': -37.819528, 'log': 144.974979, 'lux': 12.708},
#  {'lat': -37.819525, 'log': 144.974968, 'lux': 13.196},
#  {'lat': -37.819518, 'log': 144.974943, 'lux': 5.376},
#  {'lat': -37.819499, 'log': 144.974892, 'lux': 5.376},
#  {'lat': -37.819498, 'log': 144.974888, 'lux': 6.256},
#  {'lat': -37.819366, 'log': 144.974528, 'lux': 7.82},
#  {'lat': -37.819365, 'log': 144.974523, 'lux': 8.504},
#  {'lat': -37.819364, 'log': 144.974515, 'lux': 10.557},
#  {'lat': -37.819354, 'log': 144.974485, 'lux': 55.23},
#  {'lat': -37.819349, 'log': 144.974472, 'lux': 57.674},
#  {'lat': -37.819346, 'log': 144.974464, 'lux': 42.717},
#  {'lat': -37.819345, 'log': 144.974459, 'lux': 54.35},
#  {'lat': -37.819715, 'log': 144.975506, 'lux': 9.971},
#  {'lat': -37.819691, 'log': 144.975449, 'lux': 3.812},
#  {'lat': -37.81969, 'log': 144.975445, 'lux': 4.497},
#  {'lat': -37.819674, 'log': 144.975398, 'lux': 10.753},
#  {'lat': -37.819671, 'log': 144.97539, 'lux': 9.482},
#  {'lat': -37.819664, 'log': 144.975372, 'lux': 6.061},
#  {'lat': -37.819663, 'log': 144.975365, 'lux': 6.647},
#  {'lat': -37.819661, 'log': 144.975357, 'lux': 7.038},
#  {'lat': -37.819659, 'log': 144.975342, 'lux': 9.091},
#  {'lat': -37.819442, 'log': 144.974759, 'lux': 2.248},
#  {'lat': -37.819438, 'log': 144.97475, 'lux': 1.955},
#  {'lat': -37.819435, 'log': 144.974741, 'lux': 1.466},
#  {'lat': -37.819428, 'log': 144.974724, 'lux': 4.79},
#  {'lat': -37.819421, 'log': 144.974703, 'lux': 10.362},
#  {'lat': -37.81965, 'log': 144.975309, 'lux': 18.377},
#  {'lat': -37.81964, 'log': 144.975282, 'lux': 9.775},
#  {'lat': -37.819621, 'log': 144.975223, 'lux': 19.844},
#  {'lat': -37.819611, 'log': 144.975197, 'lux': 11.241},
#  {'lat': -37.81961, 'log': 144.975194, 'lux': 10.948},
#  {'lat': -37.819607, 'log': 144.975187, 'lux': 8.309},
#  {'lat': -37.819606, 'log': 144.975183, 'lux': 8.113},
#  {'lat': -37.819595, 'log': 144.975159, 'lux': 7.038},
#  {'lat': -37.819591, 'log': 144.975146, 'lux': 8.895},
#  {'lat': -37.819585, 'log': 144.975131, 'lux': 12.708},
#  {'lat': -37.819584, 'log': 144.975128, 'lux': 11.73},
#  {'lat': -37.819576, 'log': 144.975109, 'lux': 8.113},
#  {'lat': -37.819417, 'log': 144.97469, 'lux': 27.273},
#  {'lat': -37.819416, 'log': 144.974687, 'lux': 34.702},
#  {'lat': -37.819415, 'log': 144.974683, 'lux': 37.537},
#  {'lat': -37.81941, 'log': 144.974674, 'lux': 38.416},
#  {'lat': -37.819406, 'log': 144.974662, 'lux': 41.74},
#  {'lat': -37.819162, 'log': 144.973976, 'lux': 75.758},
#  {'lat': -37.819136, 'log': 144.973918, 'lux': 23.754},
#  {'lat': -37.819135, 'log': 144.973915, 'lux': 19.257},
#  {'lat': -37.819107, 'log': 144.973827, 'lux': 10.655},
#  {'lat': -37.819093, 'log': 144.973796, 'lux': 4.888},
#  {'lat': -37.819089, 'log': 144.973788, 'lux': 5.083},
#  {'lat': -37.819087, 'log': 144.973783, 'lux': 5.767},
#  {'lat': -37.81931, 'log': 144.945852, 'lux': 49.951},
#  {'lat': -37.819334, 'log': 144.945784, 'lux': 42.424},
#  {'lat': -37.819344, 'log': 144.94575, 'lux': 33.92},
#  {'lat': -37.819349, 'log': 144.945719, 'lux': 29.912},
#  {'lat': -37.819359, 'log': 144.945671, 'lux': 28.641},
#  {'lat': -37.81936, 'log': 144.945665, 'lux': 28.739},
#  {'lat': -37.81937, 'log': 144.945623, 'lux': 36.559},
#  {'lat': -37.819376, 'log': 144.945602, 'lux': 35.582},
#  {'lat': -37.819318, 'log': 144.974398, 'lux': 3.128},
#  {'lat': -37.819315, 'log': 144.974391, 'lux': 2.444},
#  {'lat': -37.819307, 'log': 144.97437, 'lux': 2.639},
#  {'lat': -37.819294, 'log': 144.974335, 'lux': 29.13},
#  {'lat': -37.819288, 'log': 144.974319, 'lux': 61.388},
#  {'lat': -37.819281, 'log': 144.974299, 'lux': 40.762},
#  {'lat': -37.819275, 'log': 144.974284, 'lux': 49.951},
#  {'lat': -37.819255, 'log': 144.974225, 'lux': 3.421},
#  {'lat': -37.819247, 'log': 144.97421, 'lux': 3.91},
#  {'lat': -37.819231, 'log': 144.97417, 'lux': 34.115},
#  {'lat': -37.819223, 'log': 144.974144, 'lux': 62.17},
#  {'lat': -37.819211, 'log': 144.97411, 'lux': 51.613},
#  {'lat': -37.819189, 'log': 144.974051, 'lux': 4.301},
#  {'lat': -37.819187, 'log': 144.974044, 'lux': 4.594},
#  {'lat': -37.81939, 'log': 144.945557, 'lux': 32.258},
#  {'lat': -37.819392, 'log': 144.945552, 'lux': 32.258},
#  {'lat': -37.819401, 'log': 144.945521, 'lux': 33.529},
#  {'lat': -37.819414, 'log': 144.945464, 'lux': 50.831},
#  {'lat': -37.819434, 'log': 144.945366, 'lux': 97.165},
#  {'lat': -37.819437, 'log': 144.945353, 'lux': 84.262},
#  {'lat': -37.819454, 'log': 144.945307, 'lux': 71.359},
#  {'lat': -37.819077, 'log': 144.973748, 'lux': 7.82},
#  {'lat': -37.819073, 'log': 144.97374, 'lux': 4.985},
#  {'lat': -37.819138, 'log': 144.946501, 'lux': 23.851},
#  {'lat': -37.819139, 'log': 144.946499, 'lux': 23.363},
#  {'lat': -37.81915, 'log': 144.946457, 'lux': 20.626},
#  {'lat': -37.819165, 'log': 144.946378, 'lux': 12.512},
#  {'lat': -37.819167, 'log': 144.946359, 'lux': 11.339},
#  {'lat': -37.819168, 'log': 144.94635, 'lux': 11.437},
#  {'lat': -37.819174, 'log': 144.946312, 'lux': 13.392},
#  {'lat': -37.819184, 'log': 144.946259, 'lux': 19.453},
#  {'lat': -37.819205, 'log': 144.946183, 'lux': 19.844},
#  {'lat': -37.819214, 'log': 144.946136, 'lux': 15.738},
#  {'lat': -37.819225, 'log': 144.94611, 'lux': 15.934},
#  {'lat': -37.819239, 'log': 144.946066, 'lux': 19.159},
#  {'lat': -37.819253, 'log': 144.946016, 'lux': 26.784},
#  {'lat': -37.819284, 'log': 144.945919, 'lux': 29.13},
#  {'lat': -37.819214, 'log': 144.945656, 'lux': 20.43},
#  {'lat': -37.819206, 'log': 144.945702, 'lux': 25.806},
#  {'lat': -37.81919, 'log': 144.945784, 'lux': 19.55},
#  {'lat': -37.811367, 'log': 144.975418, 'lux': 2.639},
#  {'lat': -37.802566, 'log': 144.97058, 'lux': 1.857},
#  {'lat': -37.820378, 'log': 144.941725, 'lux': 25.806},
#  {'lat': -37.82037, 'log': 144.941745, 'lux': 32.649},
#  {'lat': -37.820368, 'log': 144.941751, 'lux': 34.115},
#  {'lat': -37.820353, 'log': 144.941806, 'lux': 45.552},
#  {'lat': -37.820347, 'log': 144.941824, 'lux': 47.214},
#  {'lat': -37.820346, 'log': 144.941828, 'lux': 46.432},
#  {'lat': -37.819047, 'log': 144.946298, 'lux': 25.22},
#  {'lat': -37.80282, 'log': 144.970618, 'lux': 0.098},
#  {'lat': -37.802818, 'log': 144.970627, 'lux': 0.0},
#  {'lat': -37.802817, 'log': 144.970629, 'lux': 0.0},
#  {'lat': -37.802815, 'log': 144.970634, 'lux': 0.098},
#  {'lat': -37.802807, 'log': 144.97065, 'lux': 0.587},
#  {'lat': -37.8028, 'log': 144.970665, 'lux': 1.369},
#  {'lat': -37.802795, 'log': 144.970676, 'lux': 1.857},
#  {'lat': -37.802773, 'log': 144.970737, 'lux': 1.857},
#  {'lat': -37.802678, 'log': 144.971012, 'lux': 1.173},
#  {'lat': -37.802671, 'log': 144.971035, 'lux': 0.489},
#  {'lat': -37.811615, 'log': 144.974976, 'lux': 9.482},
#  {'lat': -37.811616, 'log': 144.974976, 'lux': 9.384},
#  {'lat': -37.802006, 'log': 144.971375, 'lux': 1.466},
#  {'lat': -37.802018, 'log': 144.971354, 'lux': 1.466},
#  {'lat': -37.802042, 'log': 144.971309, 'lux': 0.782},
#  {'lat': -37.802063, 'log': 144.971289, 'lux': 0.489},
#  {'lat': -37.802077, 'log': 144.97128, 'lux': 0.489},
#  {'lat': -37.802097, 'log': 144.971258, 'lux': 0.587},
#  {'lat': -37.802579, 'log': 144.971295, 'lux': 0.196},
#  {'lat': -37.80257, 'log': 144.970573, 'lux': 1.271},
#  {'lat': -37.802599, 'log': 144.970524, 'lux': 0.587},
#  {'lat': -37.802638, 'log': 144.970459, 'lux': 1.271},
#  {'lat': -37.802653, 'log': 144.970436, 'lux': 2.346},
#  {'lat': -37.802675, 'log': 144.97041, 'lux': 6.256},
#  {'lat': -37.802685, 'log': 144.970398, 'lux': 12.903},
#  {'lat': -37.802687, 'log': 144.970394, 'lux': 12.414},
#  {'lat': -37.802689, 'log': 144.97039, 'lux': 15.64},
#  {'lat': -37.811457, 'log': 144.975063, 'lux': 15.738},
#  {'lat': -37.819042, 'log': 144.94632, 'lux': 27.761},
#  {'lat': -37.819042, 'log': 144.946322, 'lux': 27.761},
#  ...]
